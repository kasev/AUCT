# %%
### Prerequisties
# most of the packages are available via anaconda
# some of them require to be installed separately

# some of the packages (especially nltk) are necessary only for preprocessing
# feel free to ignore them and move directly into later sections

import os
import pandas as pd
import numpy as np
import nltk
import pickle
import json
import sys
import re

import csv

from bs4 import BeautifulSoup
import xml.etree.cElementTree as ET

### for plotting
import matplotlib.pyplot as plt

import gspread

from gspread_dataframe import get_as_dataframe, set_with_dataframe

# a few other packages are imported in the section on visualizing distances

# %%
### to establish connection with google drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
### to work with GoogleSheets

from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials

gc = gspread.authorize(GoogleCredentials.get_application_default())

# %% [markdown]
# # To start with parsed data

# %%
### read the file from GoogleDrive

### path in the VK drive - other users have to modify accordingly...
CSEL_raw_df = pd.read_csv("/content/gdrive/My Drive/aaa_computation/AUCTORITATES/AUCTORITATES B - extraction of biblical references from footnotes/v3.3 (implementation of abbrs from JarKub)/data/CSEL_raw.csv", names=["file_name", "author", "title", "volume","text"])

# %%
CSEL_raw_df
# Out:
#                           file_name                 author  \
# 0    stoa0045a.stoa001.opp-lat1.xml                    NaN
# 1    stoa0045a.stoa001.opp-lat2.xml                    NaN
# 2     stoa0162.stoa004.opp-lat3.xml             Hieronymus
# 3     stoa0162.stoa004.opp-lat2.xml             Hieronymus
# 4     stoa0162.stoa004.opp-lat1.xml             Hieronymus
# 5     stoa0162.stoa024.opp-lat1.xml             Hieronymus
# 6    stoa0215a.stoa002.opp-lat1.xml    Optatus Milevitanus
# 7    stoa0215a.stoa001.opp-lat1.xml    Optatus Milevitanus
# 8    stoa0089a.stoa002.opp-lat1.xml    Claudianus Mamertus
# 9    stoa0089a.stoa001.opp-lat1.xml    Claudianus Mamertus
# 10   stoa0233h.stoa001.opp-lat1.xml  Paulinus Petricordiae
# 11   stoa0114a.stoa011.opp-lat1.xml               Ennodius
# 12   stoa0114a.stoa002.opp-lat1.xml               Ennodius
# 13   stoa0114a.stoa005.opp-lat1.xml               Ennodius
# 14   stoa0114a.stoa004.opp-lat1.xml               Ennodius
# 15   stoa0114a.stoa003.opp-lat1.xml               Ennodius
# 16   stoa0114a.stoa014.opp-lat1.xml               Ennodius
# 17   stoa0114a.stoa013.opp-lat1.xml               Ennodius
# 18   stoa0114a.stoa012.opp-lat1.xml               Ennodius
# 19   stoa0114a.stoa015.opp-lat1.xml               Ennodius
# 20   stoa0114a.stoa008.opp-lat1.xml               Ennodius
# 21   stoa0114a.stoa006.opp-lat2.xml               Ennodius
# 22   stoa0114a.stoa001.opp-lat1.xml               Ennodius
# 23   stoa0114a.stoa007.opp-lat1.xml               Ennodius
# 24   stoa0180a.stoa002.opp-lat1.xml    Lucifer Calaritanus
# 25   stoa0180a.stoa005.opp-lat1.xml    Lucifer Calaritanus
# 26   stoa0180a.stoa004.opp-lat1.xml    Lucifer Calaritanus
# 27   stoa0180a.stoa003.opp-lat1.xml    Lucifer Calaritanus
# 28   stoa0180a.stoa006.opp-lat1.xml    Lucifer Calaritanus
# 29   stoa0180a.stoa001.opp-lat1.xml    Lucifer Calaritanus
# ..                              ...                    ...
# 248  stoa0245a.stoa001.opp-lat1.xml       Faustus Reiensis
# 249  stoa0223a.stoa001.opp-lat2.xml  Paulinus Petricordiae
# 250   stoa0251.stoa001.opp-lat1.xml             Augustinus
# 251  stoa0104a.stoa010.opp-lat1.xml              Cyprianus
# 252  stoa0104a.stoa011.opp-lat1.xml              Cyprianus
# 253  stoa0104a.stoa002.opp-lat1.xml              Cyprianus
# 254  stoa0104a.stoa005.opp-lat1.xml              Cyprianus
# 255  stoa0104a.stoa004.opp-lat1.xml              Cyprianus
# 256  stoa0104a.stoa003.opp-lat1.xml              Cyprianus
# 257  stoa0104a.stoa014.opp-lat1.xml              Cyprianus
# 258  stoa0104a.stoa013.opp-lat1.xml              Cyprianus
# 259  stoa0104a.stoa012.opp-lat1.xml              Cyprianus
# 260  stoa0104a.stoa015.opp-lat1.xml              Cyprianus
# 261  stoa0104a.stoa008.opp-lat1.xml              Cyprianus
# 262  stoa0104a.stoa006.opp-lat1.xml              Cyprianus
# 263  stoa0104a.stoa001.opp-lat1.xml              Cyprianus
# 264  stoa0104a.stoa007.opp-lat1.xml              Cyprianus
# 265  stoa0104a.stoa009.opp-lat1.xml              Cyprianus
# 266  stoa0292a.stoa004.opp-lat1.xml              Cyprianus
# 267   stoa0111.stoa001.opp-lat3.xml              Anonymous
# 268  stoa0278a.stoa001.opp-lat1.xml              Anonymous
# 269   stoa0119.stoa002.opp-lat1.xml              Eugippius
# 270   stoa0119.stoa003.opp-lat1.xml              Eugippius
# 271   stoa0119.stoa001.opp-lat2.xml              Eugippius
# 272   stoa0117.stoa002.opp-lat1.xml              Eucherius
# 273   stoa0117.stoa004.opp-lat1.xml              Eucherius
# 274   stoa0117.stoa003.opp-lat1.xml              Eucherius
# 275   stoa0117.stoa001.opp-lat1.xml              Eucherius
# 276  stoa0234e.stoa002.opp-lat1.xml          Priscillianus
# 277  stoa0234e.stoa001.opp-lat1.xml          Priscillianus
#
#                                             title   volume  \
# 0     Epistulae Imperatorum Pontificum Aliorum, I  unknown
# 1    Epistulae Imperatorum Pontificum Aliorum, II  unknown
# 2                              Epistulae, 120-154  unknown
# 3                               Epistulae, 71-120  unknown
# 4                                 Epistulae, 1-70  unknown
# 5                          In Hieremiam Prophetam  unknown
# 6                   Contra Parmenianum Donatistam  unknown
# 7                   Contra Parmenianum Donatistam  unknown
# 8                                 De Statu Animae  unknown
# 9                                 De Statu Animae  unknown
# 10                                        Carmina  unknown
# 11                                      Epistulae  unknown
# 12                                      Epistulae  unknown
# 13                                      Epistulae  unknown
# 14                                      Epistulae  unknown
# 15                                      Epistulae  unknown
# 16                                      Epistulae  unknown
# 17                                      Epistulae  unknown
# 18                                      Epistulae  unknown
# 19                                      Epistulae  unknown
# 20                                      Epistulae  unknown
# 21                                      Epistulae  unknown
# 22                                      Epistulae  unknown
# 23                                      Epistulae  unknown
# 24              De non conveniendo cum haereticis  unknown
# 25              De non conveniendo cum haereticis  unknown
# 26              De non conveniendo cum haereticis  unknown
# 27              De non conveniendo cum haereticis  unknown
# 28              De non conveniendo cum haereticis  unknown
# 29              De non conveniendo cum haereticis  unknown
# ..                                            ...      ...
# 248                                     De Gratia  unknown
# 249                                       Carmina  unknown
# 250                                Contra Felicem  unknown
# 251                                    Ad Donatum  unknown
# 252                                    Ad Donatum  unknown
# 253                                    Ad Donatum  unknown
# 254                                    Ad Donatum  unknown
# 255                                    Ad Donatum  unknown
# 256                                    Ad Donatum  unknown
# 257                                    Ad Donatum  unknown
# 258                                    Ad Donatum  unknown
# 259                                     Epistulae  unknown
# 260                                    Ad Donatum  unknown
# 261                                    Ad Donatum  unknown
# 262                                    Ad Donatum  unknown
# 263                                    Ad Donatum  unknown
# 264                                    Ad Donatum  unknown
# 265                                    Ad Donatum  unknown
# 266                                  Heptateuchos  unknown
# 267                      Itinerarium Burdigalense  unknown
# 268                      Itinerarium Burdigalense  unknown
# 269                   Epistula ad Probam Virginem  unknown
# 270                   Epistula ad Probam Virginem  unknown
# 271                              Vita S. Severini  unknown
# 272            Formulae Spiritalis Intelligentiae  unknown
# 273            Formulae Spiritalis Intelligentiae  unknown
# 274            Formulae Spiritalis Intelligentiae  unknown
# 275            Formulae Spiritalis Intelligentiae  unknown
# 276                                     Tractatus  unknown
# 277                                     Tractatus  unknown
#
#                                                   text
# 0    \n\n\n (1.) QVAE GESTA SUNT INTER LIBERIUM ET ...
# 1    \n\n\n\n(105.)\n\n\n\n            SACRO ET BEA...
# 2    \n\n\n\nCXXI. AD ALGASIAM LIBER QVAESTIONUM UN...
# 3    \n\n\n\n\nLXXI. AD LUCINUM BAETICUM. \n\n\n\nN...
# 4    \n\n\nS. EVSEBII HIERONVMI EPISTVLAE I-LXX. \n...
# 5    \n\n\n\n\nPROLOGUS. \n\n\n\n  Post explanation...
# 6    \n\n\n\nAppendix decem monumentorum ueterum ad...
# 7    \n\n\n\nLIBER PRIMUS. \n\n\nCunctos nos christ...
# 8    \n\n\nCLAVDIANI MAMERTI EPISTVLAE DVAE. EPISTV...
# 9    \n\n\n\nEPISTVLA FAVSTI. \n\nQuaeris a me, reu...
# 10   \n\n\nPOMPONII UERSUS AD GRATIAM DOMINI. \n\n\...
# 11   \n\n\nV. [EVCHARISTICVM DE VITA SVA.] IN NOMIN...
# 12   \n\n\nX. BENEDICTIO CEREI. \n\nDignum et iustu...
# 13   \n\n\nIIII. DE VITA BEATI ANTONI MONACHI. PRAE...
# 14   \n\n\nDICTIONES. \n\n\n\nI. DICTIO IN NATALI L...
# 15   \n\n\nMAGNI FELICIS ENNODI CARMINA. \n\n\n LIB...
# 16   \n\n\nVII. PRAECEPTVM QVANDO IVSSI SVNT OMNES ...
# 17   \n\n\nVIII. PETITORIVM QVO ABSOLVTVS EST GERON...
# 18   \n\n\nII. LIBELLVS ADVERSVS EOS QVI CONTRA SVN...
# 19   \n\n\nIII. VITA BEATISSIMI VIRI EPIPHANI EPISC...
# 20   \n\n\nMAGNI FELICIS ENNODI EPISTVLARVM. LIBRI ...
# 21   \n\n\nI. PANEGVRICVS DICTVS CLEMENTISSIMO REGI...
# 22   \n\n\nVIIII. BENEDICTIO CEREI.\n\nDignam et iu...
# 23   \n\n\nVI. ENNODIVS AMBROSIO ET BEATO. \n\nDeo ...
# 24   \n\n\nIV. DE NON PARCENDO IN DEVM DELINQVENTIB...
# 25   \n\n\nVI. EPISTVLAE LVCIFERI ET ALIORVM. \n\n\...
# 26   \n\n\nIII DE SANCTO ATHANASIO. \n\n\n\nLIBER I...
# 27   \n\n\nII. DE REGIBUS APOSTATICIS. \n\n\nVsitat...
# 28   \n\n\nV. MORIENDUM ESSE PRO DEI FILIO. \n\n\nD...
# 29   \n\n\nI. DE NON CONVENIENDO CVM HAERETICIS. \n...
# ..                                                 ...
# 248  \n\n\n\nRURICII EPISTULARUM LIBER PRIMUS. \n\n...
# 249  \n\n\nPAULINI EVXAPICTIKOC. \n\n\n\nPRAEFATIO....
# 250  \n\n\nVIIII. SECUNDINI MANICHAEI AD SANCTUM AU...
# 251  \n\n\nDE CATHOLICAE ECCLESIAE VNITATE. \n\nCum...
# 252  \n\n\n\nDE ZELO ET LIVORE\n\nZelare quod bonum...
# 253  \n\n\nAD DEMETRIANVM\n\nOblatrantem te et adue...
# 254  \n\n\nAD FORTVNATVM. \n\n\n\nDesiderasti, Fort...
# 255  \n\n\nDE HABITV VIRGINVM. \n\nDisciplina custo...
# 256  \n\n\nDE BONO PATIENTIAE. \n\nDe patientia loc...
# 257  \n\n\nTHASCI CAECILI CVPRIANI AD QVIRINVM (TES...
# 258  \n\n\nSENTENTIAE EPISCOPORVM NVMERO LXXXVII DE...
# 259  \n\n\n\nEpistula I. \n\n\n\nCVPRIANVS PRESBVTE...
# 260  \n\n\nDE DOMINICA ORATIONE. \n\nEuangelica pra...
# 261  \n\n\nDE MORTALITATE. \n\nEtsi aput plurimos u...
# 262  \n\n\nQVOD IDOLA DII NON SINT. \n\nDeos non es...
# 263  \n\n\nTHASCI CAECILI CVPRIANI AD DONATUM. \n\n...
# 264  \n\n\nDE LAPSIS. \n\nPax ecce, dilectissimi fr...
# 265  \n\n\nDE OPERE ET ELEEMOSVNIS. \n\nMulta et ma...
# 266  \n\n\nEiusdem carminis interpolatum exemplar. ...
# 267  \n\n\n(MVLTA DESVNT)\n\n\n\n  ostendebantur iu...
# 268  \n\n\nCiuitas Hierusalem habens portas maiores...
# 269  \n\n\nEVGIPPII EPISTVLA AD PROBAM VIRGINEM. \n...
# 270  \n\n\nEVGIPPII. EXCERPTORVM EX, OPERIBVS S. AV...
# 271  \n\n\n\nEPISTOLA EVGIPPII PRESBVTERI AD PASCAS...
# 272  \n\n\nFORMULAE SPIRITALIS INTELLEGENTIAE. \n\n...
# 273  \n\n\nPASSIO AGAUNENSIUM MARTVRUM. \n\n\nSanct...
# 274  \n\n\n\nLIBER PRIMUS. \n\n\nPRAEFATIO AD SALON...
# 275  \n\n\nDE LAUDE HEREMI\n\n AD HILARIUM LIRINENS...
# 276  \n\n\n\nI. PRISCILLIANI TRACTATVS VNDECIM IN C...
# 277  \n\n\n\nPROLOGUS PRISCILLIANI IN CANONES EPIST...
#
# [278 rows x 5 columns]

# %%
authors_kuben = get_as_dataframe(gc.open_by_url('https://docs.google.com/spreadsheets/d/1F9EKced2JVW4a34Wu3XYLZ-kaZGP6Qt3Nh0GQjdp3to/edit?usp=sharing').worksheet("Authors"))

# %%
authors_kuben

# %%
### what unique authors are hidden behind the tag author

print(CSEL_raw_df["author"].unique())
# Out:
# [nan 'Hieronymus' 'Optatus Milevitanus' 'Claudianus Mamertus'
#  'Paulinus Petricordiae' 'Ennodius' 'Lucifer Calaritanus'
#  'Hilarius Pictaviensis' 'Cyprianus' 'Sulpicius Severus' 'Iuvencius'
#  'Anonymous' 'Paulinus Nolanus' 'Pseudo-Hilarius' 'Tertullianus'
#  'Minutius Felix' 'Eucherius' 'Sedulius' 'Salvianus' 'Arnobius'
#  'Pseudo-Cyprianus' 'Boethius' 'Victor Vitensis'
#  'Victorinus Petavionensis' 'Paulinus\n\t\t\t\t\t\t\t\tPetricordiae'
#  'Lactantius' 'Pseudo-Augustinus' 'Orosius' 'Priscillianus'
#  'Flavius Iosephus' 'Ambrosius' 'Evagrius' 'Augustinus' 'Rufinus'
#  'Faustus Reiensis' 'Commodianus' 'Cassianus' 'Iohannes Cassianus'
#  'Filastrius' 'Eugippius']

# %%
len(CSEL_raw_df["author"].unique())
# Out:
# 40

# %%
### transform the author column to string type
CSEL_raw_df["author"] = CSEL_raw_df["author"].astype(str)

# %%
### replace disturbing characters from authors' names
CSEL_raw_df["author"] = CSEL_raw_df["author"].replace({
    "\n" : " ",
    "\t" : "",
    "nan" : "unknown",
    "Anonymous" : "unknown",
    "Iohannes Cassianus" : "Cassianus",   
    }, regex=True)
sorted(CSEL_raw_df["author"].unique().tolist())
# Out:
# ['Ambrosius',
#  'Arnobius',
#  'Augustinus',
#  'Boethius',
#  'Cassianus',
#  'Claudianus Mamertus',
#  'Commodianus',
#  'Cyprianus',
#  'Ennodius',
#  'Eucherius',
#  'Eugippius',
#  'Evagrius',
#  'Faustus Reiensis',
#  'Filastrius',
#  'Flavius Iosephus',
#  'Hieronymus',
#  'Hilarius Pictaviensis',
#  'Iuvencius',
#  'Lactantius',
#  'Lucifer Calaritanus',
#  'Minutius Felix',
#  'Optatus Milevitanus',
#  'Orosius',
#  'Paulinus Nolanus',
#  'Paulinus Petricordiae',
#  'Priscillianus',
#  'Pseudo-Augustinus',
#  'Pseudo-Cyprianus',
#  'Pseudo-Hilarius',
#  'Rufinus',
#  'Salvianus',
#  'Sedulius',
#  'Sulpicius Severus',
#  'Tertullianus',
#  'Victor Vitensis',
#  'Victorinus Petavionensis',
#  'unknown']

# %%
len(CSEL_raw_df)
# Out:
# 278

# %%
CSEL_raw_df[CSEL_raw_df["author"]=="unknown"]["file_name"].tolist()
# Out:
# ['stoa0045a.stoa001.opp-lat1.xml',
#  'stoa0045a.stoa001.opp-lat2.xml',
#  'stoa0227b.stoa001.opp-lat1.xml',
#  'stoa0329.stoa001.opp-lat1.xml',
#  'stoa0028e.stoa001.opp-lat1.xml',
#  'stoa0028e.stoa001.opp-lat2.xml',
#  'stoa0329c.stoa001.opp-lat1.xml',
#  'stoa0117p.stoa001.opp-lat1.xml',
#  'stoa0054.stoa001a.opp-lat1.xml',
#  'stoa0007.stoa002.opp-lat1.xml',
#  'stoa0111.stoa001.opp-lat3.xml',
#  'stoa0278a.stoa001.opp-lat1.xml']

# %%
### merge rows with the same author
CSEL_grouped_df = CSEL_raw_df.groupby(["author"]).sum()
CSEL_grouped_df.reset_index(level=[0], inplace=True)
CSEL_grouped_df.head(5)
# Out:
#        author                                          file_name  \
# 0   Ambrosius  stoa0022.stoa021.opp-lat1.xmlstoa0022.stoa019....
# 1    Arnobius                      stoa0034.stoa001.opp-lat1.xml
# 2  Augustinus  stoa0120d.stoa001.opp-lat1.xmlstoa0040.stoa056...
# 3    Boethius  stoa0058.stoa001.opp-lat3.xmlstoa0058.stoa007....
# 4   Cassianus  stoa0076c.stoa002.opp-lat2.xmlstoa0076c.stoa00...
#
#                                                title  \
# 0  HexameronDe IacobDe IacobDe IacobHexameronExpo...
# 1                                  Adversus Nationes
# 2  Contra FelicemDe Perfectione Iustitiae Hominis...
# 3  De Consolatione PhilosophiaeCommentaria in Por...
# 4              InstitutionesInstitutionesConlationes
#
#                                               volume  \
# 0  unknownunknownunknownunknownunknownunknownunkn...
# 1                                            unknown
# 2  unknownunknownunknownunknownunknownunknownunkn...
# 3                              unknownunknownunknown
# 4                              unknownunknownunknown
#
#                                                 text
# 0  \n\n\n\n[LIBER PRIMVS.]\n\n De paradiso in sup...
# 1  \n\n\n\nLIBER PRIMVS\n\nQuoniam comperi nonnul...
# 2  \n\n\n1. EUODII DE FIDE CONTRA MANICHAEOS. \n\...
# 3  \n\n\nANICII MANLII SEVERINI BOETHII\n\n\nPHIL...
# 4  \n\n\n\nPRAEFATIO. \n\n\nUeteris instrumenti n...

# %%
len(CSEL_grouped_df)
# Out:
# 37

# %%
authors_word_counts = {}
for author, text in zip(CSEL_grouped_df["author"].tolist(), CSEL_grouped_df["text"].tolist()):
    authors_word_counts[author] = len(text.split())

# %%
authors_word_counts
# Out:
# {'Ambrosius': 885580,
#  'Arnobius': 93920,
#  'Augustinus': 3523400,
#  'Boethius': 155451,
#  'Cassianus': 337862,
#  'Claudianus Mamertus': 62407,
#  'Commodianus': 63889,
#  'Cyprianus': 691880,
#  'Ennodius': 173599,
#  'Eucherius': 55442,
#  'Eugippius': 370282,
#  'Evagrius': 20585,
#  'Faustus Reiensis': 140744,
#  'Filastrius': 40146,
#  'Flavius Iosephus': 47413,
#  'Hieronymus': 740652,
#  'Hilarius Pictaviensis': 80588,
#  'Iuvencius': 44853,
#  'Lactantius': 376422,
#  'Lucifer Calaritanus': 105594,
#  'Minutius Felix': 39577,
#  'Optatus Milevitanus': 76746,
#  'Orosius': 242516,
#  'Paulinus Nolanus': 264778,
#  'Paulinus Petricordiae': 125985,
#  'Priscillianus': 46662,
#  'Pseudo-Augustinus': 155884,
#  'Pseudo-Cyprianus': 110456,
#  'Pseudo-Hilarius': 1195,
#  'Rufinus': 41078,
#  'Salvianus': 106197,
#  'Sedulius': 112702,
#  'Sulpicius Severus': 89301,
#  'Tertullianus': 349441,
#  'Victor Vitensis': 39620,
#  'Victorinus Petavionensis': 44145,
#  'unknown': 341418}

# %%
### check the number of words
len((" ".join(CSEL_grouped_df["text"].tolist())).split())
# Out:
# 10198410

# %% [markdown]
# # Bibl Abbreviations

# %%
abbr_kase_df = get_as_dataframe(gc.open_by_url('https://docs.google.com/spreadsheets/d/1vWUsY1moh6b5A27YDxPSuibayXNLRUV97Hz9TICyBBo/edit?usp=sharing').worksheet("replace_abbr"))

# %%
repl_tuple = list(abbr_kase_df.itertuples(index=False, name=None))
print(repl_tuple[:10])
# Out:
# [('Gn ', 'Gen. '), ('Genes.', 'Gen.'), ('Ex.', 'Exo.'), ('Lv.', 'Lev.'), ('Nm.', 'Num.'), ('Dt.', 'Deut'), ('I Sm.', '1Sam.'), ('1Sm.', '1Sam.'), ('1 Sam.', '1Sam.'), ('II Sm.', '2Sam.')]

# %%
len(repl_tuple)
# Out:
# 150

# %%
### upload abbreviatians variants as found by Mr. Kuben into a dataframe

abbr_kuben = get_as_dataframe(gc.open_by_url("https://docs.google.com/spreadsheets/d/15_acFNFaTUgTW4DODk4hdMcgvGeyQlTbx783gTrEXhI/edit?usp=sharing").worksheet("List 1"))
abbr_kuben.head(5)
# Out:
#    Book_ID     Full_name   Abbr1   Abbr2  Abbr3  Abbr4      Abbr5    Abbr6  \
# 0      1.0       Genesis    Gen.  Genes.   Gon.   Qen.       Oen.      NaN
# 1      2.0        Exodus     Ex.   Exod.    Ei.    E*.        Er.       EL
# 2      3.0     Leviticus  Levit.  Leuit.   Lev.   LeY.      Leu.      Len.
# 3      4.0     Numerorum    Num.    Nam.   Nom.  NUID.      Nurn.   NumBr.
# 4      5.0  Deuteronomii   Deut.   Dent.  Deot.  Deat.  Deuteron.  Deuter.
#
#    Unnamed: 8 Unnamed: 9     ...     Unnamed: 17 Unnamed: 18 Unnamed: 19  \
# 0         NaN        NaN     ...             NaN         NaN         NaN
# 1       Eiod.      Ezod.     ...             NaN         NaN         NaN
# 2      Leoit.        NaN     ...             NaN         NaN         NaN
# 3      Nomer.      Nuin.     ...             NaN         NaN         NaN
# 4  Deuteroii.    Deater.     ...             NaN         NaN         NaN
#
#   Unnamed: 20 Unnamed: 21 Unnamed: 22 Unnamed: 23 Unnamed: 24 Unnamed: 25  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 26
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#
# [5 rows x 27 columns]

# %%
### upload the table of different forms of biblical abbr (from DZ)

abbr_conv_df = get_as_dataframe(gc.open_by_key("1byVbRwnQ058--0ud1_NBt2xgIhuiV7LK1BmCm67CTxA").worksheet("AbbrevConverter"))
abbr_conv_df[6:11]
# Out:
#     Book_ID SBL_handbook_of_style CSEL_VK CSEL_OGL English_full Latin1 Latin2  \
# 6       1.0                   Gen    Gen.      NaN      Genesis     Gn     Gn
# 7       2.0                  Exod    Exo.      NaN       Exodus     Ex     Ex
# 8       3.0                   Lev    Lev.      NaN    Leviticus     Lv     Lv
# 9       4.0                   Num    Num.      NaN      Numbers     Nm     Nm
# 10      5.0                  Deut   Deut.      NaN  Deuteronomy     Dt     Dt
#
#        Latin_full Czech     Czech_full     ...      Unnamed: 24 Unnamed: 25  \
# 6         Genesis    Gn        Genesis     ...              NaN         NaN
# 7          Exodus    Ex         Exodus     ...              NaN         NaN
# 8       Leviticus    Lv      Leviticus     ...              NaN         NaN
# 9          Numeri    Nu         Numeri     ...              NaN         NaN
# 10  Deuteronomium    Dt  Deuteronomium     ...              NaN         NaN
#
#    Unnamed: 26  Unnamed: 27  Unnamed: 28  Unnamed: 29  Unnamed: 30  \
# 6          NaN          NaN          NaN          NaN          NaN
# 7          NaN          NaN          NaN          NaN          NaN
# 8          NaN          NaN          NaN          NaN          NaN
# 9          NaN          NaN          NaN          NaN          NaN
# 10         NaN          NaN          NaN          NaN          NaN
#
#     Unnamed: 31  Unnamed: 32  Unnamed: 33
# 6           NaN          NaN          NaN
# 7           NaN          NaN          NaN
# 8           NaN          NaN          NaN
# 9           NaN          NaN          NaN
# 10          NaN          NaN          NaN
#
# [5 rows x 34 columns]

# %%
### we can navigate  through the converter by "Book_ID" variable

abbr_conv_df.loc[abbr_conv_df["Book_ID"]==5, "CSEL_VK"].values[0]
# Out:
# 'Deut.'

# %%
for row in abbr_kuben.values.tolist():
  if row[0]>0:
    replaced_abbr = abbr_conv_df.loc[abbr_conv_df["Book_ID"]==float(row[0]), "CSEL_VK"].values[0]
    for element in row[2:]:
      if "nan" not in str(element):
        tuple_pair = (element, replaced_abbr)
        if tuple_pair not in repl_tuple:
          repl_tuple.append(tuple_pair)
len(repl_tuple)
# Out:
# 453

# %%
print(repl_tuple)
# Out:
# [('Gn ', 'Gen. '), ('Genes.', 'Gen.'), ('Ex.', 'Exo.'), ('Lv.', 'Lev.'), ('Nm.', 'Num.'), ('Dt.', 'Deut'), ('I Sm.', '1Sam.'), ('1Sm.', '1Sam.'), ('1 Sam.', '1Sam.'), ('II Sm.', '2Sam.'), ('2 Sam.', '2Sam.'), ('Ios.', 'Josh.'), ('Idc.', 'Judg.'), ('Jdg.', 'Judg.'), ('1 Reg.', '1Kgs.'), ('II Reg.', '2Kgs.'), ('2 Reg.', '2Kgs.'), ('2 Rg.', '2Kgs.'), ('II Rg.', '2Kgs.'), ('2Rg.', '2Kgs.'), ('2 Ki.', '2Kgs.'), (' II Ki.', '2Kgs.'), ('I Reg.', '1Kgs.'), ('1 Rg.', '1Kgs.'), ('I Rg.', '1Kgs.'), ('1Rg.', '1Kgs.'), ('1 Ki.', '1Kgs.'), ('I Ki.', '1Kgs.'), ('2 Ch.', '2Chr.'), ('II Ch.', '2Chr.'), ('2 Chr.', '2Chr.'), ('II Chr.', '2Chr.'), ('2 Par.', '2Chr.'), ('II Par.', '2Chr.'), ('1 Ch.', '1Chr.'), ('I Ch.', '1Chr.'), ('1 Chr.', '1Chr.'), ('I Chr.', '1Chr.'), ('1 Par.', '1Chr.'), ('I Par.', '1Chr.'), ('Est.', 'Esth.'), ('Hiob', 'Job'), ('Iob', 'Job'), ('PB.', 'Psa.'), ('Psal.', 'Psa.'), ('Ps.', 'Psa.'), ('Ecc.', 'Eccl.'), ('Ecl.', 'Eccl.'), ('Prov.', 'Pro.'), ('Prou.', 'Pro.'), ('Prv.', 'Pro.'), ('Son.', 'Song.'), ('Cant.', 'Song.'), ('Can.', 'Song.'), ('Ca.', 'Song.'), ('Ct.', 'Song.'), ('Is.', 'Isa.'), ('Es.', 'Isa.'), ('Isah.', 'Isa.'), ('Ier.', 'Jer.'), ('Ir.', 'Jer.'), ('Ioel', 'Joel'), ('Joe.', 'Joel'), ('Amo.', 'Amos'), ('Oba.', 'Obad.'), ('Jon.', 'Jonah'), ('Zec.', 'Zech.'), ('Tob.', 'Tb.'), ('Idt.', 'Sap.'), ('Eccli.', 'Sir.'), ('II Mcc.', '2Mcc.'), ('I Mcc.', '1Mcc.'), ('Matth.', 'Matt.'), ('Mattli.', 'Matt.'), ('Mt.', 'Matt.'), ('Mk.', 'Mark'), ('Mc.', 'Mark'), ('Marc.', 'Mark'), ('Lk.', 'Luke'), ('Lc.', 'Luke'), ('Lnc.', 'Luke'), ('Luc.', 'Luke'), ('Joan.', 'John'), ('Joh.', 'John'), ('Ioh.', 'John'), ('Io.', 'John'), ('Act.', 'Acts'), ('2 Cor.', '2Cor.'), ('II \\(Jor.', '2Cor.'), ('II Cor.', '2Cor.'), ('I Cor.', '1Cor.'), ('1 Cor.', '1Cor.'), ('I \\(Jor.', '1Cor.'), ('Phlm', 'Phil.'), ('Phi.', 'Phil.'), ('Ephes.', 'Eph.'), ('Galat.', 'Gal.'), ('2 Thess.', '2Thess.'), ('II Thess.', '2Thess.'), ('II Th.', '2Thess.'), ('2Thes.', '2Thess.'), ('1 Thess.', '1Thess.'), ('I Thess.', '1Thess.'), ('I Th.', '1Thess.'), ('1Thes.', '1Thess.'), ('II Tim.', '2Tim.'), ('2 Tim.', '2Tim.'), ('I Tim.', '1Tim.'), ('1 Tim.', '1Tim.'), ('Phm', 'Phlm'), ('Jam.', 'Jas.'), ('II Petro', '2Pet.'), ('II Petr.', '2Pet.'), ('2 Petr.', '2Pet.'), ('2 Pe.', '2Pet.'), ('II Pe.', '2Pet.'), ('2 Pt.', '2Pet.'), ('II Pt.', '2Pet.'), ('2 Pet.', '2Pet.'), ('II Pet.', '2Pet.'), ('I Petro', '1Pet.'), ('1 Petr.', '1Pet.'), ('I Petr.', '1Pet.'), ('1 Pe.', '1Pet.'), ('I Pe.', '1Pet.'), ('1 Pt.', '1Pet.'), ('I Pt.', '1Pet.'), ('1 Pet.', '1Pet.'), ('I Pet.', '1Pet.'), (' loh.', ' Ioh.'), (' lo.', ' Ioh.'), ('III Ioh.', '3John.'), ('III Io.', '3John.'), ('II Ioh.', '2John'), ('II Io.', '2John'), ('I Ioh.', '1John'), ('I Io.', '1John'), ('1 Jo.', '1John.'), ('2 Jo.', '2John.'), ('3 Jo.', '3John.'), ('1 John.', '1John.'), ('2 John.', '2John.'), ('3 John.', '3John.'), ('Iac.', 'Jas.'), ('lac.', 'Jas.'), ('Jac.', 'Jas.'), ('Iud.', 'Jud.'), ('Jud.', 'Jude'), ('Apc.', 'Rev.'), ('Apoc.', 'Rev.'), ('Gen.', 'Gen.'), ('Gon.', 'Gen.'), ('Qen.', 'Gen.'), ('Oen.', 'Gen.'), ('Exod.', 'Exo.'), ('Ei.', 'Exo.'), ('E*.', 'Exo.'), ('Er.', 'Exo.'), ('EL', 'Exo.'), ('Eiod.', 'Exo.'), ('Ezod.', 'Exo.'), ('Levit.', 'Lev.'), ('Leuit.', 'Lev.'), ('Lev.', 'Lev.'), ('LeY.', 'Lev.'), ('Leu. ', 'Lev.'), ('Len.', 'Lev.'), ('Leoit.', 'Lev.'), ('Num.', 'Num.'), ('Nam.', 'Num.'), ('Nom.', 'Num.'), ('NUID.', 'Num.'), ('Nurn.', 'Num.'), ('NumBr.', 'Num.'), ('Nomer.', 'Num.'), ('Nuin.', 'Num.'), ('Deut.', 'Deut.'), ('Dent.', 'Deut.'), ('Deot.', 'Deut.'), ('Deat.', 'Deut.'), ('Deuteron.', 'Deut.'), ('Deuter.', 'Deut.'), ('Deuteroii.', 'Deut.'), ('Deater.', 'Deut.'), ('Uenter.', 'Deut.'), ('neuter.', 'Deut.'), ('Jos.', 'Josh.'), ('los.', 'Josh.'), ('Jud.', 'Judg.'), ('Iud.', 'Judg.'), ('Ind.', 'Judg.'), ('Iad.', 'Judg.'), ('I Sam. ', '1Sam.'), ('II Sam.', '2Sam.'), ('III Reg.', '1Kgs.'), ('m Beg.', '1Kgs.'), ('III Beg.', '1Kgs.'), ('in Reg.', '1Kgs.'), ('Regn, III', '1Kgs.'), ('Regn. III', '1Kgs.'), ('Kegn. ...

# %%
repl_tuple.to_pickle ???

# %%
### we will only replace " " with "_"for now

# %%
CSEL_raw_df["text"].replace(replace_abbr, regex=True, inplace=True)

# %%
CSEL_raw_df["text"]
# Out:
# 0      \n\n\n (1.) QVAE GESTA SUNT INTER LIBERIUM ET ...
# 1      \n\n\n\n(105.)\n\n\n\n            SACRO ET BEA...
# 2      \n\n\n\nCXXI. AD ALGASIAM LIBER QVAESTIONUM UN...
# 3      \n\n\n\n\nLXXI. AD LUCINUM BAETICUM. \n\n\n\nN...
# 4      \n\n\nS. EVSEBII HIERONVMI EPISTVLAE I-LXX. \n...
# 5      \n\n\n\n\nPROLOGUS. \n\n\n\n  Post explanation...
# 6      \n\n\n\nAppendix decem monumentorum ueterum ad...
# 7      \n\n\n\nLIBER PRIMUS. \n\n\nCunctos nos christ...
# 8      \n\n\nCLAVDIANI MAMERTI EPISTVLAE DVAE. EPISTV...
# 9      \n\n\n\nEPISTVLA FAVSTI. \n\nQuaeris a me, reu...
# 10     \n\n\nPOMPONII UERSUS AD GRATIAM DOMINI. \n\n\...
# 11     \n\n\nV. [EVCHARISTICVM DE VITA SVA.] IN NOMIN...
# 12     \n\n\nX. BENEDICTIO CEREI. \n\nDignum et iustu...
# 13     \n\n\nIIII. DE VITA BEATI ANTONI MONACHI. PRAE...
# 14     \n\n\nDICTIONES. \n\n\n\nI. DICTIO IN NATALI L...
# 15     \n\n\nMAGNI FELICIS ENNODI CARMINA. \n\n\n LIB...
# 16     \n\n\nVII. PRAECEPTVM QVANDO IVSSI SVNT OMNES ...
# 17     \n\n\nVIII. PETITORIVM QVO ABSOLVTVS EST GERON...
# 18     \n\n\nII. LIBELLVS ADVERSVS EOS QVI CONTRA SVN...
# 19     \n\n\nIII. VITA BEATISSIMI VIRI EPIPHANI EPISC...
# 20     \n\n\nMAGNI FELICIS ENNODI EPISTVLARVM. LIBRI ...
# 21     \n\n\nI. PANEGVRICVS DICTVS CLEMENTISSIMO REGI...
# 22     \n\n\nVIIII. BENEDICTIO CEREI.\n\nDignam et iu...
# 23     \n\n\nVI. ENNODIVS AMBROSIO ET BEATO. \n\nDeo ...
# 24     \n\n\nIV. DE NON PARCENDO IN DEVM DELINQVENTIB...
# 25     \n\n\nVI. EPISTVLAE LVCIFERI ET ALIORVM. \n\n\...
# 26     \n\n\nIII DE SANCTO ATHANASIO. \n\n\n\nLIBER I...
# 27     \n\n\nII. DE REGIBUS APOSTATICIS. \n\n\nVsitat...
# 28     \n\n\nV. MORIENDUM ESSE PRO DEI FILIO. \n\n\nD...
# 29     \n\n\nI. DE NON CONVENIENDO CVM HAERETICIS. \n...
#                              ...
# 248    \n\n\n\nRURICII EPISTULARUM LIBER PRIMUS. \n\n...
# 249    \n\n\nPAULINI EVXAPICTIKOC. \n\n\n\nPRAEFATIO....
# 250    \n\n\nVIIII. SECUNDINI MANICHAEI AD SANCTUM AU...
# 251    \n\n\nDE CATHOLICAE ECCLESIAE VNITATE. \n\nCum...
# 252    \n\n\n\nDE ZELO ET LIVORE\n\nZelare quod bonum...
# 253    \n\n\nAD DEMETRIANVM\n\nOblatrantem te et adue...
# 254    \n\n\nAD FORTVNATVM. \n\n\n\nDesiderasti, Fort...
# 255    \n\n\nDE HABITV VIRGINVM. \n\nDisciplina custo...
# 256    \n\n\nDE BONO PATIENTIAE. \n\nDe patientia loc...
# 257    \n\n\nTHASCI CAECILI CVPRIANI AD QVIRINVM (TES...
# 258    \n\n\nSENTENTIAE EPISCOPORVM NVMERO LXXXVII DE...
# 259    \n\n\n\nEpistula I. \n\n\n\nCVPRIANVS PRESBVTE...
# 260    \n\n\nDE DOMINICA ORATIONE. \n\nEuangelica pra...
# 261    \n\n\nDE MORTALITATE. \n\nEtsi aput plurimos u...
# 262    \n\n\nQVOD IDOLA DII NON SINT. \n\nDeos non es...
# 263    \n\n\nTHASCI CAECILI CVPRIANI AD DONATUM. \n\n...
# 264    \n\n\nDE LAPSIS. \n\nPax ecce, dilectissimi fr...
# 265    \n\n\nDE OPERE ET ELEEMOSVNIS. \n\nMulta et ma...
# 266    \n\n\nEiusdem carminis interpolatum exemplar. ...
# 267    \n\n\n(MVLTA DESVNT)\n\n\n\n  ostendebantur iu...
# 268    \n\n\nCiuitas Hierusalem habens portas maiores...
# 269    \n\n\nEVGIPPII EPISTVLA AD PROBAM VIRGINEM. \n...
# 270    \n\n\nEVGIPPII. EXCERPTORVM EX, OPERIBVS S. AV...
# 271    \n\n\n\nEPISTOLA EVGIPPII PRESBVTERI AD PASCAS...
# 272    \n\n\nFORMULAE SPIRITALIS INTELLEGENTIAE. \n\n...
# 273    \n\n\nPASSIO AGAUNENSIUM MARTVRUM. \n\n\nSanct...
# 274    \n\n\n\nLIBER PRIMUS. \n\n\nPRAEFATIO AD SALON...
# 275    \n\n\nDE LAUDE HEREMI\n\n AD HILARIUM LIRINENS...
# 276    \n\n\n\nI. PRISCILLIANI TRACTATVS VNDECIM IN C...
# 277    \n\n\n\nPROLOGUS PRISCILLIANI IN CANONES EPIST...
# Name: text, Length: 278, dtype: object

# %%
### saving the dataframe into a pickle file
CSEL_raw_df.to_pickle("data/CSEL_modified_df.pkl")
