# %%
### Prerequisties
# most of the packages are available via anaconda
# some of them require to be installed separately

# some of the packages (especially nltk) are necessary only for preprocessing
# feel free to ignore them and move directly into later sections

import os
import pandas as pd
import numpy as np
import nltk
import pickle
import json
import sys
import re

import csv
from bs4 import BeautifulSoup
import xml.etree.cElementTree as ET

from gensim import corpora, models, similarities
### drawing on a basic tutorial: https://radimrehurek.com/gensim/tut1.html#corpus-streaming-one-document-at-a-time
### we use it here basically only for generating the vector model

import numpy as np 
from sklearn.feature_extraction.text import CountVectorizer

### for plotting
import matplotlib.pyplot as plt
import plotly.plotly as py
import plotly.graph_objs as go
### import cufflinks as cf - to connect plotly and pandas

import gspread
from gspread_dataframe import get_as_dataframe, set_with_dataframe

# a few other packages are imported in the section on visualizing distances

# %% [markdown]
# ## To start with preprocessed CSEL and PL

# %%
CSEL_modified_df = pd.read_pickle("data/CSEL_modified_df.pkl")
CSEL_modified_df.head(5)
# Out:
#                         file_name      author  \
# 0  stoa0045a.stoa001.opp-lat1.xml     unknown
# 1  stoa0045a.stoa001.opp-lat2.xml     unknown
# 2   stoa0162.stoa004.opp-lat3.xml  Hieronymus
# 3   stoa0162.stoa004.opp-lat2.xml  Hieronymus
# 4   stoa0162.stoa004.opp-lat1.xml  Hieronymus
#
#                                           title  \
# 0   Epistulae Imperatorum Pontificum Aliorum, I
# 1  Epistulae Imperatorum Pontificum Aliorum, II
# 2                            Epistulae, 120-154
# 3                             Epistulae, 71-120
# 4                               Epistulae, 1-70
#
#                                                 text
# 0  \n\n\n (1.) QVAE GESTA SUNT INTER LIBERIUM ET ...
# 1  \n\n\n\n(105.)\n\n\n\n            SACRO ET BEA...
# 2  \n\n\n\nCXXI. AD ALGASIAM LIBER QVAESTIONUM UN...
# 3  \n\n\n\n\nLXXI. AD LUCINUM BAETICUM. \n\n\n\nN...
# 4  \n\n\nS. EVSEBII HIERONVMI EPISTVLAE I-LXX. \n...

# %%
first_text = CSEL_modified_df["text"][0]
first_text[:400]
# Out:
# '\n\n\n (1.) QVAE GESTA SUNT INTER LIBERIUM ET FELICEM EPISCOPOS.  \n\nTemporibus Constantii imperatoris filii Constantini durior \n            orta est persecutio Christianorum ab impiis haereticis Arrianis \n            annitente Constantio, qui et Athanasium episcopum resistentem \n            haereticis persecutus est et, ut damnaretur ab omnibus episcopis, \n            imperauit. quod etiam metu princ'

# %%
### FUNCTION: replace Roman numbers with arabic

def roman_to_int(n):
    n = str(n.upper())
    numeral_map = zip(
        (1000, 900, 500, 400, 100, 90, 50, 40, 10, 9, 5, 4, 1),
        ('M', 'CM', 'D', 'CD', 'C', 'XC', 'L', 'XL', 'X', 'IX', 'V', 'IV', 'I')
    )
    i = 0
    result = 0
    for integer, numeral in numeral_map:
        while n[i:i + len(numeral)] == numeral:
            result += integer
            i += len(numeral)  
    return result

# %%
### set up the credentials
from oauth2client.service_account import ServiceAccountCredentials
scope = ['https://spreadsheets.google.com/feeds',
         'https://www.googleapis.com/auth/drive']
creds = ServiceAccountCredentials.from_json_keyfile_name('jupgsheets.json', scope)
gc = gspread.authorize(creds)

# %%
### open spreadsheet from url
sh = gc.open_by_key("1byVbRwnQ058--0ud1_NBt2xgIhuiV7LK1BmCm67CTxA")
### open particular worksheet
worksheet = sh.worksheet("AbbrevConverter")

# %%
### upload the worksheet into dataframe
abbrevConverter_df = get_as_dataframe(worksheet)
### select only its part as a 
abbrevConverter_df = abbrevConverter_df[6:82]

# %%
abbrevConverter_df.head(5)
# Out:
#     Book_ID SBL_handbook_of_style CSEL_VK CSEL_OGL English_full Latin1 Latin2  \
# 6       1.0                   Gen    Gen.      NaN      Genesis     Gn     Gn
# 7       2.0                  Exod    Exo.      NaN       Exodus     Ex     Ex
# 8       3.0                   Lev    Lev.      NaN    Leviticus     Lv     Lv
# 9       4.0                   Num    Num.      NaN      Numbers     Nm     Nm
# 10      5.0                  Deut   Deut.      NaN  Deuteronomy     Dt     Dt
#
#        Latin_full Czech     Czech_full     ...      Unnamed: 24 Unnamed: 25  \
# 6         Genesis    Gn        Genesis     ...              NaN         NaN
# 7          Exodus    Ex         Exodus     ...              NaN         NaN
# 8       Leviticus    Lv      Leviticus     ...              NaN         NaN
# 9          Numeri    Nu         Numeri     ...              NaN         NaN
# 10  Deuteronomium    Dt  Deuteronomium     ...              NaN         NaN
#
#    Unnamed: 26  Unnamed: 27  Unnamed: 28  Unnamed: 29  Unnamed: 30  \
# 6          NaN          NaN          NaN          NaN          NaN
# 7          NaN          NaN          NaN          NaN          NaN
# 8          NaN          NaN          NaN          NaN          NaN
# 9          NaN          NaN          NaN          NaN          NaN
# 10         NaN          NaN          NaN          NaN          NaN
#
#     Unnamed: 31  Unnamed: 32  Unnamed: 33
# 6           NaN          NaN          NaN
# 7           NaN          NaN          NaN
# 8           NaN          NaN          NaN
# 9           NaN          NaN          NaN
# 10          NaN          NaN          NaN
#
# [5 rows x 34 columns]

# %%
abbrevConverter_df.set_index("CSEL_VK", inplace=True)

# %%
abbrevConverter_df.loc[word]["Classification_genre_DZ1"]
# Out:
# 'historical'

# %%
### the list of biblical books abbreviations we will use

bib_books = abbrevConverter_df["CSEL_VK"].tolist()
print(bib_books[:10])
# Out:
# ['Gen.', 'Exo.', 'Lev.', 'Num.', 'Deut.', 'Josh.', 'Judg.', 'Ruth', '1Sam.', '2Sam.']

# %%
CSEL_modified_df.head(5)
# Out:
#                         file_name      author  \
# 0  stoa0045a.stoa001.opp-lat1.xml     unknown
# 1  stoa0045a.stoa001.opp-lat2.xml     unknown
# 2   stoa0162.stoa004.opp-lat3.xml  Hieronymus
# 3   stoa0162.stoa004.opp-lat2.xml  Hieronymus
# 4   stoa0162.stoa004.opp-lat1.xml  Hieronymus
#
#                                           title  \
# 0   Epistulae Imperatorum Pontificum Aliorum, I
# 1  Epistulae Imperatorum Pontificum Aliorum, II
# 2                            Epistulae, 120-154
# 3                             Epistulae, 71-120
# 4                               Epistulae, 1-70
#
#                                                 text
# 0  \n\n\n (1.) QVAE GESTA SUNT INTER LIBERIUM ET ...
# 1  \n\n\n\n(105.)\n\n\n\n            SACRO ET BEA...
# 2  \n\n\n\nCXXI. AD ALGASIAM LIBER QVAESTIONUM UN...
# 3  \n\n\n\n\nLXXI. AD LUCINUM BAETICUM. \n\n\n\nN...
# 4  \n\n\nS. EVSEBII HIERONVMI EPISTVLAE I-LXX. \n...

# %%
sh = gc.open_by_url('https://docs.google.com/spreadsheets/d/1vWUsY1moh6b5A27YDxPSuibayXNLRUV97Hz9TICyBBo/edit?usp=sharing')
###worksheet = sh.add_worksheet(title="CSEL_overview", rows=1, cols=4)
worksheet = sh.worksheet("CSEL_overview")

# %%
worksheet.clear()
# Out:
# {'spreadsheetId': '1vWUsY1moh6b5A27YDxPSuibayXNLRUV97Hz9TICyBBo',
#  'clearedRange': 'CSEL_overview!A1:D203'}

# %%
### they do not like it at google
overview = []
for file_name, author, title, text in zip(CSEL_modified_df["file_name"], CSEL_modified_df["author"], CSEL_modified_df["title"], CSEL_modified_df["text"]):
    overview.append([file_name, author, title, len(text.split())])

# %%
### export the overview into spreadsheet
    set_with_dataframe(worksheet, pd.DataFrame(overview))

# %%
### from the content of the footnotes we will ignore everything except the abbreviations
bib_abbr = []
# go throug every note one by one
for file_name, author, title, text in zip(CSEL_modified_df["file_name"], CSEL_modified_df["author"], CSEL_modified_df["title"], CSEL_modified_df["text"]):
    # find all matches between words in the text and abbr. of biblical books
    author_text_split = text.split()
    for num, word in enumerate(author_text_split):
        if word in bib_books:
            word_plus_one = author_text_split[num+1]
                
            word_plus_two = author_text_split[num+2]
            word_minus_one = author_text_split[num-1]
            words_original = " ".join([word, word_plus_one, word_plus_two])
            if (word_plus_one == "cap.") or (word_plus_one == "c."):
                word_plus_one = author_text_split[num+2]
                word_plus_two = author_text_split[num+3]
            try: ### identify any roman number in chapters and replace them by arabic
                found = re.search(r'(^(?=[MDCLXVI])M*(C[MD]|D?C{0,3})(X[CL]|L?X{0,3})(I[XV]|V?I{0,3})(\b))', word_plus_one, flags=re.IGNORECASE).groups()[0]
                if not found == "":
                    word_plus_one = word_plus_one.replace(found, str(roman_to_int(found)))
            except:
                pass
            try: 
                chapterverse = re.search('(\d+)(\.|\,|\:)(\d+)', word_plus_one, flags=re.IGNORECASE).groups()
                word_plus_one = chapterverse[0]
                word_plus_two = chapterverse[2]
            except:
                pass
            if not word_plus_one[0].isdigit():
                word_plus_one = ""
                precision_type = "no_chapter_"
            else:
                word_plus_one = re.search(r'(\d+)', word_plus_one, flags=re.IGNORECASE).groups()[0]
                precision_type = "chapter_"
            if word_plus_two.startswith("v."):
                word_plus_two.replace("v.", "")
            if not word_plus_two[0].isdigit():
                word_plus_two = ""
                precision_type = precision_type + "no_verse"
            else:
                word_plus_two = re.search(r'((\d+)(\-\d+)?)', word_plus_two, flags=re.IGNORECASE).groups()[0]
                precision_type = precision_type + "verse"
            genre = abbrevConverter_df.loc[word]["Classification_genre_DZ1"]
            testament = abbrevConverter_df.loc[word]["Classification_testament"]
            czech = abbrevConverter_df.loc[word]["Czech"]
            ### to match instances with more verses (Gen. 5.7-14)
            if word_minus_one.lower() == "cf.":
                citation_or_allusion = "a"
            else:
                citation_or_allusion = "c"
            more_verses = re.match(r'(\d+)(\-)(\d+)', word_plus_two)
            if more_verses is not None:
                beginning = int(more_verses.groups()[0])
                end = int(more_verses.groups()[2])
                words_modified = "_".join([word.replace(".","").lower(), word_plus_one, str(beginning) + "to" + str(end)])
                bib_abbr.append([file_name, author, title, word_minus_one, words_original, citation_or_allusion, words_modified, "child", precision_type, word, word_plus_one, str(beginning), str(end), czech, genre, testament])
                ###    beginning = beginning + 1
                ###while (beginning <= end):
                ###    words_modified = "_".join([word.replace(".","").lower(), word_plus_one, str(beginning)])
                ###    bib_abbr.append([file_name, author, title, words_original, words_modified])
                ###    beginning = beginning + 1
            else:
                words_modified = "_".join([word.replace(".","").lower(), word_plus_one, word_plus_two])
                bib_abbr.append([file_name, author, title, word_minus_one, words_original, citation_or_allusion, words_modified, "single", precision_type, word, word_plus_one, word_plus_two,  0, czech, genre, testament])

# %%
bib_abbr_df = pd.DataFrame(bib_abbr, columns=["file_name", "author", "Work", "word_before", "text_as_found", "Citation_or_allusion", "condenced_expression", "Composite_type", "completion?", "CSEL_VK", "Composite_reference_chapter", "Composite_reference_firstverse", "Composite_reference_lastverse", "Czech", "Classification_genre_DZ1", "Classification_testament"])   
bib_abbr_df.head(5)
# Out:
#                         file_name   author  \
# 0  stoa0045a.stoa001.opp-lat1.xml  unknown
# 1  stoa0045a.stoa001.opp-lat1.xml  unknown
# 2  stoa0045a.stoa001.opp-lat1.xml  unknown
# 3  stoa0045a.stoa001.opp-lat1.xml  unknown
# 4  stoa0045a.stoa001.opp-lat1.xml  unknown
#
#                                           Work word_before text_as_found  \
# 0  Epistulae Imperatorum Pontificum Aliorum, I           1   Luke 12, 20
# 1  Epistulae Imperatorum Pontificum Aliorum, I         cf.    Acts 9, 15
# 2  Epistulae Imperatorum Pontificum Aliorum, I           6     Gal. 1. 8
# 3  Epistulae Imperatorum Pontificum Aliorum, I           9    Gal. 2, 18
# 4  Epistulae Imperatorum Pontificum Aliorum, I          14   John 14. 27
#
#   Citation_or_allusion condenced_expression Composite_type    completion?  \
# 0                    c           luke_12_20         single  chapter_verse
# 1                    a            acts_9_15         single  chapter_verse
# 2                    c              gal_1_8         single  chapter_verse
# 3                    c             gal_2_18         single  chapter_verse
# 4                    c           john_14_27         single  chapter_verse
#
#   CSEL_VK Composite_reference_chapter Composite_reference_firstverse  \
# 0    Luke                          12                             20
# 1    Acts                           9                             15
# 2    Gal.                           1                              8
# 3    Gal.                           2                             18
# 4    John                          14                             27
#
#   Composite_reference_lastverse Czech Classification_genre_DZ1  \
# 0                             0     L               historical
# 1                             0    Sk               historical
# 2                             0    Ga    admonishing/normative
# 3                             0    Ga    admonishing/normative
# 4                             0     J               historical
#
#   Classification_testament
# 0                       NT
# 1                       NT
# 2                       NT
# 3                       NT
# 4                       NT

# %%
#  to save the abbreviations into a file
with open("data/CSEL_bib_abbr.pkl", "wb") as f:
    pickle.dump(bib_abbr_df, f)

# %%
### upload the data back and start here
file = open("data/CSEL_bib_abbr.pkl", "rb")
bib_abbr_df = pickle.load(file)

# %%
worksheet = sh.add_worksheet(title="CSEL_abbr_data", rows=1, cols=10)

# %%
worksheet = sh.worksheet("CSEL_abbr_data")

# %%
### export the data into spreadsheet
set_with_dataframe(worksheet, pd.DataFrame(bib_abbr_df))

# %%
### Overview

# %%
bib_abbr_df.columns.tolist()
# Out:
# ['file_name',
#  'author',
#  'Work',
#  'word_before',
#  'text_as_found',
#  'Citation_or_allusion',
#  'condenced_expression',
#  'Composite_type',
#  'completion?',
#  'CSEL_VK',
#  'Composite_reference_chapter',
#  'Composite_reference_firstverse',
#  'Composite_reference_lastverse',
#  'Czech',
#  'Classification_genre_DZ1',
#  'Classification_testament']

# %%
len(bib_abbr_df)
# Out:
# 27053

# %%
len(bib_abbr_df[bib_abbr_df["completion?"]=="chapter_verse"])
# Out:
# 24694

# %%
len(bib_abbr_df[bib_abbr_df["completion?"]=="chapter_no_verse"])
# Out:
# 961

# %%
len(bib_abbr_df[bib_abbr_df["completion?"]=="no_chapter_no_verse"])
# Out:
# 1112

# %%
len(bib_abbr_df[bib_abbr_df["Composite_type"]=="child"])
# Out:
# 1739

# %%
authors_bib_books = []
for author in authors_bib_abbr:
    author_bookchapterverses = []
    for element in author:
        author_bookchapterverses.append(element[1])
    authors_bib_books.append(" ".join(author_bookchapterverses))

# %%
#  to save the abbreviations into a file
with open("data/CSEL_PL_bib_abbr.pkl", "wb") as f:
    pickle.dump(authors_bib_books, f)

# %%
file = open("data/CSEL_PL_bib_abbr.pkl", "rb")
authors_bib_books = pickle.load(file)

# %%
### how many elements we have
len(" ".join(authors_bib_books).split())
# Out:
# 49981

# %%
import itertools

books_only = []
book_chapters = []
book_chapter_verses = []
for author in authors_bib_books:
    book_chapter_verses.append(re.findall(r'\w+\_\d+\_\d+', author))
    book_chapters.append(re.findall(r'\w+\_\d+.', author)) ### or add "\b" to match chapters only
    books_only.append(re.findall(r'\w+\_\_\b', author))
print("Book abbr. only: ", len(list(itertools.chain.from_iterable(books_only))), ", book and chapters: ", len(list(itertools.chain.from_iterable(book_chapters))), "book, chapter and verses: ", len(list(itertools.chain.from_iterable(book_chapter_verses))))
# Out:
# Book abbr. only:  7360 , book and chapters:  42621 book, chapter and verses:  38263

# %%
authors_overview = []
for author in authors_bib_books:
    authors_overview.append([len(re.findall(r'\w+.', author)), len(re.findall(r'\w+\_\d+.', author)), len(re.findall(r'\w+\_\d+\_\d+', author))])
authors_overview
authors_overview_df = pd.DataFrame(authors_overview, columns=["all_book_abbr", "all_book_chapters", "book_ch_v"])

# %%
file = open("data/authors_dict.pickle", "rb")
authors_dict = pickle.load(file)
authors_df = pd.DataFrame.from_dict(authors_dict, orient="index")

file = open('data/authors_word_counts.pickle', 'rb')
authors_word_counts = pickle.load(file)
authors_word_counts_df = pd.DataFrame(authors_word_counts, columns=["word_counts"])
authors_data_overview = pd.concat([authors_df, authors_word_counts_df, authors_overview_df], axis=1)

authors_data_overview.sort_values("word_counts", ascending=False, inplace=True)

with open("data/authors_data_overview.pkl", "wb") as f:
    pickle.dump(authors_data_overview, f)
authors_data_overview.to_csv("data/authors_data_overview.csv")

authors_data_overview
# Out:
#                                  0  word_counts  all_book_abbr  \
# 68                         unknown      8669518           4500
# 2                       Augustinus      7578566          18798
# 30                      Hieronymus      2773401           4120
# 28              Gregorius I Magnus      2131024           1211
# 0                        Ambrosius      1918521           5613
# 33            Isidorus Hispalensis      1878572           1224
# 4                         Boethius      1045805             53
# 36                    Leo I Magnus       884185            272
# 31                        Hilarius       816962            636
# 12                       Cyprianus       746357           1224
# 66                        Vigilius       478757             77
# 15               Dionysius Exiguus       460132            276
# 6                        Cassianus       459454            729
# 37        Leo Senonensis Episcopus       451058            235
# 29  Gregorius Turonensis Episcopus       448898            104
# 58                       Salvianus       419289            197
# 32                     Ioannes III       409057             90
# 24                        Felix IV       408129            140
# 35                      Lactantius       397971             96
# 53             Prosperus Aquitanus       393599            279
# 3              Aurelius Prudentius       390547             75
# 18                       Eugippius       370282           1384
# 27                      Gelasius I       355546            118
# 63                    Tertullianus       349441           2077
# 40   Maximus Taurinensis Episcopus       342275            321
# 50              Petrus Chrysologus       314176            114
# 67                            Zeno       290310            162
# 48                Paulinus Nolanus       264778            687
# 46                         Orosius       242516            138
# 47             Paschasius Diaconus       200198             94
# ..                             ...          ...            ...
# 11                       Cornelius        78088            168
# 45             Optatus Milevitanus        76746             96
# 8                      Commodianus        63889            133
# 7              Claudianus Mamertus        62407             35
# 17                       Eucherius        55442            193
# 26                Flavius Iosephus        47413             13
# 52                   Priscillianus        46662            894
# 60                       Sixtus II        45628             16
# 34                       Iuvencius        44853              4
# 65        Victorinus Petavionensis        44145            120
# 57                         Rufinus        41078            171
# 25                      Filastrius        40146            154
# 64                 Victor Vitensis        39620             57
# 43                  Minutius Felix        39577             38
# 9          Concilia Carthaginensia        39296             73
# 44                      Novatianus        39161             19
# 21                        Evagrius        20585            161
# 61                     Stephanus I        12501              6
# 51                Pontius Diaconus        10338             44
# 42          Miltiades (Melchiades)        10090              2
# 41         Merobaudes Scholasticus         9101              4
# 20                     Eutychianus         8051              2
# 13                       Dionysius         5611              2
# 23                         Felix I         4951              0
# 39                        Lucius I         3354              1
# 10               Concilium Romanum         2108              0
# 19           Eusebius Vercellensis         1630              0
# 56                 Pseudo-Hilarius         1195              1
# 5                            Caius         1064              0
# 14          Dionysius Alexandrinus          722              0
#
#     all_book_chapters  book_ch_v
# 68               2235       1198
# 2               18386      17784
# 30               3772       3514
# 28                357        224
# 0                4606       4390
# 33                762        123
# 4                  26         11
# 36                132         68
# 31                293        254
# 12               1084       1013
# 66                 31         18
# 15                248         17
# 6                 700        668
# 37                147         57
# 29                 44         39
# 58                174        150
# 32                 71         56
# 24                112         95
# 35                 72         54
# 53                200        158
# 3                  26          7
# 18               1367       1349
# 27                 67         33
# 63               2071       2058
# 40                 93         19
# 50                 84         28
# 67                 66         24
# 48                587        515
# 46                126         90
# 47                 80         65
# ..                ...        ...
# 11                 54          5
# 45                 94         93
# 8                 128        123
# 7                  35         35
# 17                181        181
# 26                 12          3
# 52                883        671
# 60                  7          3
# 34                  2          2
# 65                118        118
# 57                169        168
# 25                153        148
# 64                 56         54
# 43                 33         31
# 9                  29          8
# 44                 15         13
# 21                160        159
# 61                  3          0
# 51                 21          2
# 42                  0          0
# 41                  0          0
# 20                  1          0
# 13                  1          0
# 23                  0          0
# 39                  1          0
# 10                  0          0
# 19                  0          0
# 56                  1          1
# 5                   0          0
# 14                  0          0
#
# [69 rows x 5 columns]

# %%
data = [
     go.Bar(
        y=authors_data_overview[1:24]["word_counts"],
        x=authors_data_overview[1:24][0],
        name= "Total number of words",
        width=0.95,
        marker=dict(
            color='rgba(204,204,204,1)',
            )
        ),   
    go.Bar(
       y=authors_data_overview[1:24]["all_book_abbr"],
        x=authors_data_overview[1:24][0],
        name= "All biblical books abbreviations",
        yaxis="y2",
        width=0.15
        ),
    go.Bar(
        y=authors_data_overview[1:24]["all_book_chapters"],
        x=authors_data_overview[1:24][0],
        name= "Biblical books abbr. and chapters",
        yaxis="y2",
        width=0.15
        ),
    go.Bar(
        y=authors_data_overview[1:24]["book_ch_v"],
        x=authors_data_overview[1:24][0],
        name= "Bib. books abbr., chapters and verses",
        yaxis="y2",
        width=0.15
        ),
    ]


layout = go.Layout(
    barmode='group',
    title='Word couts and biblical books abbreviations counts',
    yaxis=dict(
        title="word counts",
        side="right"
    ),
    yaxis2=dict(
        title="abbrevations counts",
        overlaying="y",
        side="left"
    ),
    autosize=False,
    width=700,
    height=500,
    margin=go.Margin(
        ##l=50,
        ##r=50,
        b=200,
        ##t=100,
        ##pad=4
    ),
    legend=dict(
        x=0.5,
        y=0.8,
        # traceorder='reversed',
        font=dict(
            family='sans-serif',
            size=12,
            color='#000'
        ),
        ## bgcolor='#E2E2E2',
        ## bordercolor='#FFFFFF',
        ## borderwidth=2
    )
)

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='authors_data_overview')


### authors_data_overview.iplot(kind='bar', filename='authors_data_overview')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~kasev/48.embed" height="500px" width="700px"></iframe>

# %%
book_chapter_verses[0]
# Out:
# ['luke_4_33',
#  'isa_1_3',
#  'acts_9_34',
#  'acts_8_10',
#  'deut_32_49',
#  'deut_6_5',
#  'sap_1_4',
#  'john_4_8',
#  'gen_32_2',
#  'deut_33_23',
#  'deut_19_13',
#  'luke_7_57',
#  'john_16_3',
#  'luke_2_38',
#  'john_8_11',
#  'rom_3_28',
#  'john_5_44',
#  'luke_7_41',
#  'rom_7_14',
#  'john_4_16',
#  'luke_2_35',
#  'gen_48_22',
#  'dan_3_18',
#  'luke_8_5',
#  'acts_28_27',
#  'rom_5_5',
#  'sap_7_12',
#  'john_10_38',
#  'john_3_2',
#  'john_1_1',
#  'rom_1_24',
#  'john_8_42',
#  'john_16_27',
#  'rom_8_32',
#  'john_5_20',
#  'mark_10_18',
#  'luke_22_42',
#  'john_10_3',
#  'john_5_23',
#  'deut_21_23',
#  'luke_23_43',
#  'john_20_12',
#  'john_2_18',
#  'sap_8_13',
#  'john_1_18',
#  'acts_2_6',
#  'luke_4_51',
#  'mark_1_13',
#  'rom_1_3',
#  'deut_6_4',
#  'luke_9_26',
#  'matt_25_31',
#  'mark_8_38',
#  'sap_7_26',
#  'mark_1_25',
#  'luke_4_41',
#  'gen_5_11',
#  'mark_3_17',
#  'john_17_21',
#  'john_10_17',
#  'john_6_58',
#  'john_3_13',
#  'john_5_21',
#  'rom_4_24',
#  'john_5_26',
#  'john_6_58',
#  'john_17_5',
#  'john_13_31',
#  'john_1_3',
#  'rom_9_5',
#  'sap_7_37',
#  'rom_11_35',
#  'rom_11_35',
#  'rom_1_25',
#  'john_4_2',
#  'john_17_1',
#  'john_8_17',
#  'john_14_12',
#  'john_5_22',
#  'gen_11_7',
#  'phil_2_6',
#  'rom_5_19',
#  'john_7_8',
#  'john_13_35',
#  'john_13_31',
#  'john_12_45',
#  'john_7_28',
#  'john_12_49',
#  'john_6_17',
#  'john_12_49',
#  'john_8_38',
#  'matt_11_27',
#  'luke_17_31',
#  'luke_19_43',
#  'rom_11_20',
#  'gen_18_21',
#  'tit_1_2',
#  'dan_13_42',
#  'luke_12_10',
#  'john_20_22',
#  'rom_5_5',
#  'rom_5_5',
#  'rom_8_20',
#  'luke_4_18',
#  'luke_5_2',
#  'john_16_7',
#  'john_16_18',
#  'john_14_2',
#  'john_1_3',
#  'acts_4_12',
#  'john_5_45',
#  'john_5_6',
#  'john_14_6',
#  'john_1_5',
#  'exo_3_15',
#  'john_1_1',
#  'rom_9_20',
#  'john_12_3',
#  'john_5_7',
#  'acts_1_8',
#  'luke_7_30',
#  'john_17_5',
#  'mark_16_15',
#  'luke_11_20',
#  'rom_1_20',
#  'john_17_17',
#  'john_16_7',
#  'dan_4_21',
#  'num_11_25',
#  'num_21_6',
#  'num_14_8',
#  'rom_8_9',
#  'john_5_6',
#  'john_14_6',
#  'deut_6_13',
#  'deut_6_15',
#  'john_1_5',
#  'deut_6_4',
#  'matt_22_43',
#  'john_20_28',
#  'gen_4_3',
#  'luke_5_2',
#  'rom_3_4',
#  'luke_12_15',
#  'luke_6_8',
#  'dan_13_35',
#  'luke_1_29',
#  'luke_6_37',
#  'john_4_34',
#  'mark_9_8',
#  'gen_31_32',
#  'sap_8_7',
#  'gen_14_16',
#  'gen_41_33',
#  'gen_49_22',
#  'deut_33_16',
#  'tit_2_7',
#  'phil_4_12',
#  'mark_6_18',
#  'luke_9_36',
#  'num_16_12',
#  'num_16_21',
#  'deut_4_24',
#  'luke_16_9',
#  'john_15_14',
#  'acts_7_2',
#  'acts_8_38',
#  'acts_16_33',
#  'acts_3_15',
#  'john_4_18',
#  'acts_25_12',
#  'acts_27_43',
#  'john_21_20',
#  'luke_15_32',
#  'gen_4_9',
#  'rom_4_5',
#  'john_2_8',
#  'sap_11_24',
#  'luke_8_15',
#  'num_25_1',
#  'deut_13_3',
#  'john_4_18',
#  'john_10_4',
#  'gen_7_8',
#  'john_4_20',
#  'gen_6_1',
#  'luke_1_48',
#  'gen_17_14',
#  'john_10_12',
#  'luke_21_16',
#  'john_4_8',
#  'acts_15_38',
#  'john_1_8',
#  'john_5_29',
#  'john_3_5',
#  'luke_6_25',
#  'john_3_15',
#  'john_1_8',
#  'john_2_21',
#  'john_5_6',
#  'gen_4_11',
#  'deut_27_26',
#  'john_10_30',
#  'sap_7_47',
#  'john_4_8',
#  'rom_9_5',
#  'rom_402_1114',
#  'luke_2_52',
#  'deut_10_16',
#  'acts_10_31',
#  'luke_16_16',
#  'john_3_9',
#  'deut_18_18',
#  'luke_12_20',
#  'num_33_17',
#  'num_13_4',
#  'luke_11_52',
#  'heb_7_24',
#  'num_33_20',
#  'num_33_23',
#  'num_33_24',
#  'heb_12_1',
#  'dan_8_27',
#  'luke_5_26',
#  'rom_6_6',
#  'john_20_4',
#  'luke_2_16',
#  'num_33_30',
#  'eccl_32_24',
#  'num_33_38',
#  'eccl_28_28',
#  'num_24_5',
#  'acts_13_2',
#  'luke_1_28',
#  'eph_2_20',
#  'dan_2_54',
#  'acts_5_15',
#  'acts_10_9',
#  'acts_1_9',
#  'acts_2_11',
#  'acts_2_16',
#  'col_2_14',
#  'acts_10_9',
#  'acts_10_19',
#  'phil_2_10',
#  'rom_13_11',
#  'luke_21_25',
#  'luke_1_28',
#  'luke_2_16',
#  'gen_3_1',
#  'acts_6_6',
#  'acts_6_15',
#  'dan_6_47',
#  'gen_13_17',
#  'gen_13_18',
#  'gen_13_19',
#  'gen_13_20',
#  'jude_7_7',
#  'acts_9_15',
#  'john_21_18',
#  'dan_6_47',
#  'gen_13_17',
#  'gen_13_18',
#  'gen_13_19',
#  'gen_13_20',
#  'jude_7_7',
#  'john_3_2',
#  'john_8_50',
#  'deut_10_16',
#  'john_2_19',
#  'luke_6_5',
#  'acts_16_3',
#  'acts_16_2',
#  'gen_22_18',
#  'john_4_20',
#  'john_2_15',
#  'john_2_48',
#  'john_4_1',
#  'john_4_2',
#  'john_5_5',
#  'eccl_7_24',
#  'john_3_9',
#  'john_19_15',
#  'luke_24_40',
#  'luke_1_35',
#  'john_14_6',
#  'luke_2_14',
#  'rom_397_3',
#  'phil_2_8',
#  'john_3_8',
#  'mark_1_34',
#  'deut_32_18',
#  'gen_2_8',
#  'luke_19_40',
#  'john_4_8',
#  'john_3_16',
#  'john_4_5',
#  'john_17_5',
#  'john_12_31',
#  'john_21_15',
#  'luke_6_40',
#  'sap_6_7',
#  'gen_4_1',
#  'gen_1_58',
#  'gen_4_2',
#  'gen_25_23',
#  'gen_35_29',
#  'deut_32_50',
#  'gal_3_16',
#  'deut_34_5',
#  'deut_34_6',
#  'mark_16_19',
#  'rom_8_21',
#  'job_14_4',
#  'john_3_5',
#  'gen_4_2',
#  'gen_3_18',
#  'gen_3_17',
#  'sap_4_8',
#  'gen_25_32',
#  'deut_21_15',
#  'deut_21_16',
#  'deut_21_17',
#  'sap_2_4',
#  'sap_2_5',
#  'sap_2_6',
#  'sap_2_7',
#  'sap_2_8',
#  'luke_4_7',
#  'luke_4_3',
#  'luke_4_4',
#  'luke_4_9',
#  'luke_4_12',
#  'luke_4_5',
#  'luke_4_8',
#  'luke_4_6',
#  'sir_34_20',
#  'sir_34_21',
#  'luke_13_25',
#  'luke_13_26',
#  'luke_13_27',
#  'luke_6_21',
#  'luke_6_25',
#  'luke_23_56',
#  'john_14_2',
#  'eccl_5_12',
#  'eccl_5_9',
#  'luke_12_15',
#  'luke_12_21',
#  'gen_33_11',
#  'gen_21_10',
#  'gen_25_1',
#  'gen_30_31',
#  'gen_46_34',
#  'gen_4_4',
#  'gen_4_2',
#  'gen_4_3',
#  'deut_23_21',
#  'eccl_5_3',
#  'deut_8_11',
#  'deut_8_12',
#  'deut_8_13',
#  'deut_8_14',
#  'deut_8_17',
#  'deut_9_4',
#  'john_3_16',
#  'rom_8_32',
#  'rom_8_32',
#  'gen_22_3',
#  'gen_18_2',
#  'gen_18_6',
#  'john_8_56',
#  'gen_18_7',
#  'sap_16_28',
#  'luke_19_5',
#  'luke_19_9',
#  'gen_27_20',
#  'gen_27_20',
#  'john_5_17',
#  'num_11_23',
#  'john_14_23',
#  'john_1_48',
#  'john_1_26',
#  'luke_18_11',
#  'luke_18_13',
#  'luke_18_14',
#  'gen_27_20',
#  'luke_17_14',
#  'luke_17_15',
#  'luke_17_16',
#  'luke_17_18',
#  'gen_18_6',
#  'luke_13_21',
#  'sir_21_25',
#  'eccl_10_12',
#  'gen_4_10',
#  'luke_6_8',
#  'luke_11_13',
#  'gen_4_4',
#  'luke_21_23',
#  'sap_4_9',
#  'rom_7_23',
#  'rom_7_24',
#  'num_15_20',
#  'luke_4_4',
#  'num_15_18',
#  'num_15_19',
#  'num_15_20',
#  'num_15_21',
#  'num_18_8',
#  'gen_29_34',
#  'num_3_12',
#  'john_1_26',
#  'num_28_2',
#  'mark_11_7',
#  'john_1_29',
#  'john_8_16',
#  'luke_19_10',
#  'john_3_17',
#  'gen_18_24',
#  'num_3_12',
#  'num_35_6',
#  'john_1_14',
#  'rom_13_3',
#  'num_3_13',
#  'john_13_2',
#  'john_13_27',
#  'luke_19_5',
#  'john_2_15',
#  'luke_19_9',
#  'luke_19_8',
#  'gen_4_4',
#  'gen_41_26',
#  'gen_4_7',
#  'gen_4_5',
#  'rom_12_1',
#  'gen_25_29',
#  'gen_25_30',
#  'luke_24_42',
#  'luke_6_12',
#  'john_6_45',
#  'john_6_32',
#  'gen_1_2',
#  'gen_4_7',
#  'gen_4_7',
#  'gen_4_7',
#  'gen_4_8',
#  'gen_37_24',
#  'gen_4_10',
#  'gen_4_9',
#  'gen_4_10',
#  'gen_4_10',
#  'gen_4_12',
#  'gen_4_10',
#  'rom_6_10',
#  'gen_4_12',
#  'gen_4_13',
#  'gen_4_14',
#  'gen_4_15',
#  'gen_2_2',
#  'gen_4_15',
#  'gen_4_17',
#  'gen_4_16',
#  'gen_4_24',
#  'gen_9_25',
#  'gen_48_1',
#  'gen_48_8',
#  'gen_48_13',
#  'gen_41_51',
#  'deut_32_18',
#  'gen_41_52',
#  'gen_48_18',
#  'gen_48_20',
#  'gen_49_1',
#  'gen_49_8',
#  'gen_49_6',
#  'gen_49_5',
#  'gen_34_13',
#  'gen_48_22',
#  'gen_49_4',
#  'gen_49_7',
#  'rom_11_26',
#  'deut_33_8',
#  'deut_33_6',
#  'gen_49_8',
#  'gen_49_9',
#  'gen_49_10',
#  'gen_49_11',
#  'gen_49_12',
#  'luke_1_27',
#  'gen_49_10',
#  'john_1_27',
#  'john_3_29',
#  'john_15_1',
#  'john_1_28',
#  'luke_4_1',
#  'john_19_34',
#  'gen_49_13',
#  'rom_13_12',
#  'gen_10_15',
#  'rom_5_20',
#  'gen_49_14',
#  'deut_33_19',
#  'gen_49_16',
#  'luke_22_3',
#  'deut_33_22',
#  'gen_49_19',
#  'deut_33_20',
#  'deut_11_6',
#  'gen_49_20',
#  'rom_11_33',
#  'john_6_35',
#  'john_6_48',
#  'john_6_49',
#  'john_6_50',
#  'john_6_51',
#  'deut_33_24',
#  'deut_33_25',
#  'deut_33_26',
#  'deut_33_27',
#  'deut_33_28',
#  'gen_49_21',
#  'deut_33_23',
#  'gen_49_22',
#  'john_3_30',
#  'john_9_29',
#  'gen_37_3',
#  'luke_11_27',
#  'john_1_18',
#  'sir_24_3',
#  'deut_33_13',
#  'deut_32_39',
#  'deut_14_4',
#  'gen_49_27',
#  'acts_9_2',
#  'acts_9_2',
#  'acts_9_3',
#  'gen_35_18',
#  'acts_13_7',
#  'deut_33_12',
#  'luke_1_35',
#  'job_30_25',
#  'sir_22_11',
#  'eccl_7_4',
#  'sir_29_2',
#  'deut_23_19',
#  'sir_29_1',
#  'sir_29_10',
#  'luke_11_9',
#  'luke_11_10',
#  'luke_11_11',
#  'luke_11_12',
#  'luke_11_13',
#  'sap_2_6',
#  'sap_2_7',
#  'sap_2_8',
#  'sap_2_9',
#  'job_20_15',
#  'luke_15_4',
#  'luke_12_58',
#  'sir_20_15',
#  'eccl_3_2',
#  'eccl_3_6',
#  'eccl_1_8',
#  'eccl_1_9',
#  'eccl_1_7',
#  'deut_23_19',
#  'luke_6_24',
#  'deut_23_20',
#  'deut_23_19',
#  'deut_25_17',
#  'luke_6_34',
#  'luke_6_35',
#  'luke_6_36',
#  'deut_24_12',
#  'deut_24_13',
#  'deut_24_14',
#  'deut_24_15',
#  'deut_24_19',
#  'luke_6_35',
#  'deut_28_12',
#  'acts_3_6',
#  'acts_3_6',
#  'acts_10_20',
#  'acts_9_15',
#  'deut_28_12',
#  'deut_28_15',
#  'deut_28_4',
#  'deut_28_12',
#  'luke_11_31',
#  'acts_16_3',
#  'luke_19_14',
#  'luke_19_22',
#  'deut_28_43',
#  'deut_28_44',
#  'john_8_25',
#  'rom_10_4',
#  'luke_8_5',
#  'luke_8_12',
#  'john_19_23',
#  'acts_1_25',
#  'acts_2_6',
#  'rom_1_16',
#  'luke_7_47',
#  'rom_6_4',
#  'gen_9_23',
#  'num_16_48',
#  'sir_29_2',
#  'rom_9_28',
#  'rom_9_27',
#  'deut_24_8',
#  'luke_20_17',
#  'john_5_39',
#  'luke_20_18',
#  'deut_24_19',
#  'luke_7_41',
#  'luke_7_43',
#  'luke_7_44',
#  'luke_7_45',
#  'luke_7_46',
#  'luke_7_47',
#  'sir_29_15',
#  'sir_8_18',
#  'sir_29_20',
#  'sir_36_21',
#  'gen_19_26',
#  'gal_2_20',
#  'sir_7_2',
#  'eccl_1_2',
#  'num_35_11',
#  'num_35_13',
#  'num_35_6',
#  'num_35_25',
#  'num_35_6',
#  'luke_18_29',
#  'gen_12_1',
#  'luke_9_23',
#  'rom_11_5',
#  'luke_8_21',
#  'john_16_32',
#  'john_15_8',
#  'john_17_3',
#  'john_10_38',
#  'gen_1_26',
#  'deut_6_5',
#  'rom_1_15',
#  'rom_1_17',
#  'rom_1_20',
#  'rom_2_4',
#  'rom_2_12',
#  'rom_2_13',
#  'john_1_29',
#  'rom_3_25',
#  'acts_4_27',
#  'john_1_9',
#  'john_1_16',
#  'luke_19_17',
#  'gen_27_43',
#  'gen_27_43',
#  'gen_28_2',
#  'gen_12_117',
#  'gen_27_43',
#  'gen_27_44',
#  'gen_27_45',
#  'gen_29_28',
#  'gen_30_32',
#  'gen_32_25',
#  'gen_28_12',
#  'gen_31_33',
#  'gen_19_11',
#  'john_14_30',
#  'john_20_27',
#  'rom_4_17',
#  'john_1_29',
#  'luke_17_7',
#  'mark_6_8',
#  'luke_9_3',
#  'rom_10_15',
#  'john_14_27',
#  'gen_31_33',
#  'gen_31_1',
#  'gen_31_34',
#  'sir_9_13',
#  'gen_19_17',
#  'gen_4_10',
#  'luke_21_23',
#  'deut_10_12',
#  'john_14_31',
#  'deut_13_4',
#  'luke_3_2',
#  'deut_6_5',
#  'acts_17_28',
#  'mark_10_18',
#  'deut_30_15',
#  'luke_12_21',
#  'gen_4_15',
#  'gen_4_14',
#  'luke_10_18',
#  'luke_17_24',
#  'gen_3_14',
#  'gen_3_14',
#  'gen_8_14',
#  'gen_8_15',
#  'luke_10_4',
#  'luke_10_4',
#  'gen_3_17',
#  'luke_7_86',
#  'gen_87_17',
#  'gen_18_11',
#  'gen_27_6',
#  'luke_4_4',
#  'gen_27_4',
#  'acts_10_10',
#  'gen_27_5',
#  'gen_27_20',
#  'gen_27_27',
#  'gen_27_36',
#  'gen_27_8',
#  'gen_27_9',
#  'gen_24_68',
#  'gen_4_4',
#  'gen_28_2',
#  'sus_85_3',
#  'gen_19_15',
#  'john_1_29',
#  'rom_6_4',
#  'rom_6_6',
#  'rom_6_4',
#  'gen_2_8',
#  'mark_12_25',
#  'gen_1_7',
#  'gen_2_10',
#  'rom_8_19',
#  'sap_7_21',
#  'sap_7_22',
#  'sap_7_23',
#  'sap_7_24',
#  'sap_7_25',
#  'sap_7_26',
#  'gen_2_9',
#  'gen_3_7',
#  'gen_39_7',
#  'gen_22_1',
#  'luke_22_3',
#  'luke_10_18',
#  'gen_2_10',
#  'gen_2_10',
#  'gen_2_11',
#  'gen_2_12',
#  'gen_2_13',
#  'gen_2_14',
#  'john_7_37',
#  'gen_4_26',
#  'gen_5_24',
#  'gen_6_9',
#  'rom_1_16',
#  'gen_4_26',
#  'gen_2_15',
#  'gen_2_18',
#  'gen_2_16',
#  'john_1_1',
#  'john_10_30',
#  'john_17_22',
#  'deut_6_4',
#  'deut_6_5',
#  'gen_3_22',
#  'rom_7_7',
#  'rom_7_7',
#  'gen_3_6',
#  'luke_12_47',
#  'john_6_64',
#  'luke_19_10',
#  'rom_2_14',
#  'john_6_50',
#  'john_6_53',
#  'john_4_34',
#  'gen_1_24',
#  'luke_20_37',
#  'mark_12_26',
#  'rom_6_5',
#  'rom_6_6',
#  'rom_6_7',
#  'rom_6_8',
#  'acts_13_36',
#  'rom_6_4',
#  'rom_6_8',
#  'gen_2_18',
#  'gen_1_4',
#  'gen_1_31',
#  'gen_4_15',
#  'gen_2_18',
#  'gen_2_19',
#  'gen_2_20',
#  'gen_2_21',
#  'gen_2_22',
#  'gen_2_23',
#  'gen_1_28',
#  'gen_3_22',
#  'rom_7_23',
#  'luke_23_43',
#  'gen_3_1',
#  'rom_8_7',
#  'rom_7_23',
#  'sap_2_24',
#  'gen_3_2',
#  'gen_2_16',
#  'gen_8_3',
#  'luke_10_18',
#  'john_14_10',
#  'john_8_40',
#  'john_14_28',
#  'john_1_1',
#  'rom_7_7',
#  'rom_7_8',
#  'rom_7_23',
#  'rom_7_24',
#  'rom_7_19',
#  'gen_3_4',
#  'gen_3_5',
#  'gen_3_6',
#  'gen_3_5',
#  'gen_3_7',
#  'gen_16_1',
#  'luke_13_6',
#  'luke_12_35',
#  'gen_3_8',
#  'deut_34_10',
#  'sap_1_6',
#  'gen_3_9',
#  'gen_3_22',
#  'gen_4_9',
#  'luke_4_8',
#  'gen_28_40',
#  'gen_27_38',
#  'gen_25_27',
#  'gen_3_14',
#  'gen_3_14',
#  'gen_3_14',
#  'gen_3_14',
#  'gen_3_17',
#  'gal_2_20',
#  'gal_2_20',
#  'gen_3_17',
#  'gen_3_19',
#  'rom_7_23',
#  'gen_26_22',
#  'gen_26_23',
#  'gen_26_24',
#  'gen_26_22',
#  'eccl_1_2',
#  'rom_8_20',
#  'luke_21_26',
#  'john_1_1',
#  'mark_1_2',
#  'mal_3_1',
#  'mark_1_3',
#  'mark_1_6',
#  'luke_1_35',
#  'luke_6_27',
#  'luke_6_29',
#  'luke_6_34',
#  'luke_16_10',
#  'luke_21_26',
#  'luke_23_44',
#  'gen_3_19',
#  'gen_1_11',
#  'gen_1_11',
#  'sap_3_15',
#  'luke_1_5',
#  'john_2_2',
#  'john_2_1',
#  'luke_3_16',
#  'luke_6_48',
#  'john_1_14',
#  'john_1_1',
#  'john_8_56',
#  'mark_6_52',
#  'luke_23_21',
#  'john_14_9',
#  'john_5_19',
#  'john_2_9',
#  'john_9_6',
#  'gen_2_7',
#  'mark_2_5',
#  'john_11_43',
#  'rom_1_20',
#  'john_13_37',
#  'john_21_22',
#  'luke_10_40',
#  'luke_10_41',
#  'luke_10_42',
#  'john_12_3',
#  'rom_9_18',
#  'mark_10_48',
#  'john_21_25',
#  'luke_23_34',
#  'john_1_1',
#  'john_17_3',
#  'john_10_30',
#  'luke_22_36',
#  'luke_2_13',
#  'job_14_4',
#  'rom_3_23',
#  'rom_2_13',
#  'luke_6_46',
#  'sir_43_32',
#  'rom_2_29',
#  'john_1_47',
#  'acts_17_24',
#  'luke_23_34',
#  'acts_1_26',
#  'gen_18_1',
#  'acts_7_55',
#  'john_1_18',
#  'john_1_18',
#  'john_14_9',
#  'gen_49_28',
#  'gen_21_2',
#  'gen_2_24',
#  'gal_4_3',
#  'luke_7_28',
#  'luke_1_44',
#  'luke_1_46',
#  'luke_13_7',
#  'luke_4_19',
#  'luke_1_35',
#  'acts_1_8',
#  'acts_2_2',
#  'luke_3_4',
#  'luke_3_4',
#  'john_1_1',
#  'gen_4_10',
#  'num_12_8',
#  'gen_30_23',
#  'luke_1_44',
#  'deut_23_17',
#  'luke_4_35',
#  'luke_1_15',
#  'luke_7_28',
#  'luke_1_15',
#  'mark_2_16',
#  'luke_5_30',
#  'john_16_32',
#  'john_14_16',
#  'john_1_18',
#  'sap_7_26',
#  'john_1_9',
#  'rom_10_6',
#  'luke_1_18',
#  'gen_21_2',
#  'gen_37_3',
#  'gen_18_13',
#  'luke_1_45',
#  'luke_1_47',
#  'gen_1_27',
#  'gen_32_28',
#  'num_12_1',
#  'luke_1_44',
#  'luke_9_3',
#  'luke_9_3',
#  'john_4_2',
#  'deut_30_14',
#  'rom_10_8',
#  'acts_1_8',
#  'john_1_1',
#  'john_1_3',
#  'john_1_9',
#  'john_1_10',
#  'john_1_14',
#  'john_1_30',
#  'john_1_29',
#  'john_14_2',
#  'luke_2_9',
#  'john_14_6',
#  'num_24_17',
#  'john_14_6',
#  'john_10_11',
#  'luke_1_26',
#  'luke_2_8',
#  'mark_1_13',
#  'luke_1_85',
#  'luke_2_38',
#  'luke_2_30',
#  'john_1_37',
#  'john_8_26',
#  'luke_1_38',
#  'john_8_54',
#  'john_8_49',
#  'luke_3_22',
#  'john_14_28',
#  'john_10_30',
#  'rom_8_17',
#  'john_15_1',
#  'rom_3_20',
#  'luke_16_16',
#  'gal_3_24',
#  'mark_1_6',
#  'john_4_34',
#  'john_1_22',
#  'john_1_30',
#  ...]

# %%
authors_b_c_v = []
for author in book_chapter_verses:
    authors_b_c_v.append(" ".join(author))
### to look at first instance
authors_b_c_v[0]
# Out:
# 'luke_4_33 isa_1_3 acts_9_34 acts_8_10 deut_32_49 deut_6_5 sap_1_4 john_4_8 gen_32_2 deut_33_23 deut_19_13 luke_7_57 john_16_3 luke_2_38 john_8_11 rom_3_28 john_5_44 luke_7_41 rom_7_14 john_4_16 luke_2_35 gen_48_22 dan_3_18 luke_8_5 acts_28_27 rom_5_5 sap_7_12 john_10_38 john_3_2 john_1_1 rom_1_24 john_8_42 john_16_27 rom_8_32 john_5_20 mark_10_18 luke_22_42 john_10_3 john_5_23 deut_21_23 luke_23_43 john_20_12 john_2_18 sap_8_13 john_1_18 acts_2_6 luke_4_51 mark_1_13 rom_1_3 deut_6_4 luke_9_26 matt_25_31 mark_8_38 sap_7_26 mark_1_25 luke_4_41 gen_5_11 mark_3_17 john_17_21 john_10_17 john_6_58 john_3_13 john_5_21 rom_4_24 john_5_26 john_6_58 john_17_5 john_13_31 john_1_3 rom_9_5 sap_7_37 rom_11_35 rom_11_35 rom_1_25 john_4_2 john_17_1 john_8_17 john_14_12 john_5_22 gen_11_7 phil_2_6 rom_5_19 john_7_8 john_13_35 john_13_31 john_12_45 john_7_28 john_12_49 john_6_17 john_12_49 john_8_38 matt_11_27 luke_17_31 luke_19_43 rom_11_20 gen_18_21 tit_1_2 dan_13_42 luke_12_10 john_20_22 rom_5_5 rom_5_5 rom_8_20 luke_4_18 luke_5_2 john_16_7 john_16_18 john_14_2 john_1_3 acts_4_12 john_5_45 john_5_6 john_14_6 john_1_5 exo_3_15 john_1_1 rom_9_20 john_12_3 john_5_7 acts_1_8 luke_7_30 john_17_5 mark_16_15 luke_11_20 rom_1_20 john_17_17 john_16_7 dan_4_21 num_11_25 num_21_6 num_14_8 rom_8_9 john_5_6 john_14_6 deut_6_13 deut_6_15 john_1_5 deut_6_4 matt_22_43 john_20_28 gen_4_3 luke_5_2 rom_3_4 luke_12_15 luke_6_8 dan_13_35 luke_1_29 luke_6_37 john_4_34 mark_9_8 gen_31_32 sap_8_7 gen_14_16 gen_41_33 gen_49_22 deut_33_16 tit_2_7 phil_4_12 mark_6_18 luke_9_36 num_16_12 num_16_21 deut_4_24 luke_16_9 john_15_14 acts_7_2 acts_8_38 acts_16_33 acts_3_15 john_4_18 acts_25_12 acts_27_43 john_21_20 luke_15_32 gen_4_9 rom_4_5 john_2_8 sap_11_24 luke_8_15 num_25_1 deut_13_3 john_4_18 john_10_4 gen_7_8 john_4_20 gen_6_1 luke_1_48 gen_17_14 john_10_12 luke_21_16 john_4_8 acts_15_38 john_1_8 john_5_29 john_3_5 luke_6_25 john_3_15 john_1_8 john_2_21 john_5_6 gen_4_11 deut_27_26 john_10_30 sap_7_47 john_4_8 rom_9_5 rom_402_1114 luke_2_52 deut_10_16 acts_10_31 luke_16_16 john_3_9 deut_18_18 luke_12_20 num_33_17 num_13_4 luke_11_52 heb_7_24 num_33_20 num_33_23 num_33_24 heb_12_1 dan_8_27 luke_5_26 rom_6_6 john_20_4 luke_2_16 num_33_30 eccl_32_24 num_33_38 eccl_28_28 num_24_5 acts_13_2 luke_1_28 eph_2_20 dan_2_54 acts_5_15 acts_10_9 acts_1_9 acts_2_11 acts_2_16 col_2_14 acts_10_9 acts_10_19 phil_2_10 rom_13_11 luke_21_25 luke_1_28 luke_2_16 gen_3_1 acts_6_6 acts_6_15 dan_6_47 gen_13_17 gen_13_18 gen_13_19 gen_13_20 jude_7_7 acts_9_15 john_21_18 dan_6_47 gen_13_17 gen_13_18 gen_13_19 gen_13_20 jude_7_7 john_3_2 john_8_50 deut_10_16 john_2_19 luke_6_5 acts_16_3 acts_16_2 gen_22_18 john_4_20 john_2_15 john_2_48 john_4_1 john_4_2 john_5_5 eccl_7_24 john_3_9 john_19_15 luke_24_40 luke_1_35 john_14_6 luke_2_14 rom_397_3 phil_2_8 john_3_8 mark_1_34 deut_32_18 gen_2_8 luke_19_40 john_4_8 john_3_16 john_4_5 john_17_5 john_12_31 john_21_15 luke_6_40 sap_6_7 gen_4_1 gen_1_58 gen_4_2 gen_25_23 gen_35_29 deut_32_50 gal_3_16 deut_34_5 deut_34_6 mark_16_19 rom_8_21 job_14_4 john_3_5 gen_4_2 gen_3_18 gen_3_17 sap_4_8 gen_25_32 deut_21_15 deut_21_16 deut_21_17 sap_2_4 sap_2_5 sap_2_6 sap_2_7 sap_2_8 luke_4_7 luke_4_3 luke_4_4 luke_4_9 luke_4_12 luke_4_5 luke_4_8 luke_4_6 sir_34_20 sir_34_21 luke_13_25 luke_13_26 luke_13_27 luke_6_21 luke_6_25 luke_23_56 john_14_2 eccl_5_12 eccl_5_9 luke_12_15 luke_12_21 gen_33_11 gen_21_10 gen_25_1 gen_30_31 gen_46_34 gen_4_4 gen_4_2 gen_4_3 deut_23_21 eccl_5_3 deut_8_11 deut_8_12 deut_8_13 deut_8_14 deut_8_17 deut_9_4 john_3_16 rom_8_32 rom_8_32 gen_22_3 gen_18_2 gen_18_6 john_8_56 gen_18_7 sap_16_28 luke_19_5 luke_19_9 gen_27_20 gen_27_20 john_5_17 num_11_23 john_14_23 john_1_48 john_1_26 luke_18_11 luke_18_13 luke_18_14 gen_27_20 luke_17_14 luke_17_15 luke_17_16 luke_17_18 gen_18_6 luke_13_21 sir_21_25 eccl_10_12 gen_4_10 luke_6_8 luke_11_13 gen_4_4 luke_21_23 sap_4_9 rom_7_23 rom_7_24 num_15_20 luke_4_4 num_15_18 num_15_19 num_15_20 num_15_21 num ...

# %%
#  to save the abbreviations into a file
with open("data/CSEL_PL_b_c_v.pkl", "wb") as f:
    pickle.dump(authors_b_c_v, f)

# %%
def repl(m):
    return m.group(1)

authors_b_c = []
for author in book_chapters:
    authors_b_c.append(re.sub(r'(\w+_\d+)(\_)(\d+)?', repl, " ".join(author)))
authors_b_c[0]
# Out:
# 'luke_4  isa_1  acts_9  acts_8  deut_32  job_10 gen_3 jude_7 deut_6  sap_1  luke_7 john_1 john_7 john_4  gen_32  deut_33  deut_19  john_11 rom_12 luke_7  john_16  luke_2  john_1 gen_43 john_8  rom_3  john_5  luke_111 luke_7  john_3 rom_7  john_4  luke_2  gen_48  deut_32 dan_3  dan_3 luke_8  job_100 rom_12 acts_4 acts_28  john_1 rom_5  john_1 sap_7  john_10  john_3  john_1  rom_1  john_8  john_16  rom_8  john_5  john_8 mark_10  luke_22  phil_2 john_10  john_5  deut_21  luke_23  john_20  john__7  john_2  john_500 sap_8  john_1  rom_2 acts_2  luke_4  mark_1  rom_1  john_14 deut_6  luke_9  matt_25  mark_8  sap_7  mark_1  luke_4  acts_7 gen_5  john_3 mark_3  john_17  mark_6 john_10  john_6  john_3  john_5  rom_4  john_5  john_6 john_6  john_17  john_13  john_1  rom_9  rom_11 sap_7  rom_11  sap__37  rom_11  gen_1 rom_1  john_5 john_4  john_17  acts_4 john_8  john_14  john_5  luke_1 john_17 john_17 rom_8 gen_11  phil_2  rom_5  john_7  john_13  john_16 john_8 john_13  john_1 rom_1 john_12  john_7  john_12 john_8 john_8 john_12  john_6  john_12  john_8  heb_1 rom_4 matt_11  luke_17  luke_19  rom_11  mark_13 gen_18  matt_21 mark_12 tit_1  dan_13  john_1 rom_401 luke_12  john_20  rom_5  rom_5  rom_8  luke_4  luke_5  john_16  john_16  john_14  john_1  acts_4  john_5  john_2 john_5  john_14  john_1  exo_3  john_1  rom_9  john_12  john_5  acts_1  luke_7  john_17  john_4 mark_16  luke_11  rom_1  john_17  luke_11 john_16  sap_7 dan_4  num_11  num_21 num_21  num_14  rom_8  john_5  sap_1 john_14  deut_6  deut_6  john_1  john_13 deut_6  matt_22  john_20  sap_1 gen_4  luke_5  sap__22  john_20 rom_3  deut_6 luke_12  luke_6  dan_13  luke_1  gen_15 luke_6  john_4  mark_9  mal__109  john_14 gen_31  rom_402 luke_6 sap_7 sap_8  gen_14  gen_41  gen_49  deut_33  tit_2  phil_4  acts_12 mark_6  luke_9  num_16  num_16  deut_4  luke_16  john_15  acts_7  acts_8  acts_16  acts_10 john_3 john_6 gen_22 acts_14 rom_1 john_2 john_5 john_4 john_4 john_5 rom_9 mark_16 john_2 acts_14 rom_11 gen_22 isa_9 acts_11 acts_15 john_3 acts_3  john_4  luke_19 john_17 acts_14 acts_25  acts_27  john_21  john_3 luke_15  gen_4  luke_19 rom_1000 rom_4  john_2  sap_11  luke_8  num_25  deut_13  john_4  john_10  gen_7  john_4  gen_32 gen_6  luke_1  gen_17  john_10  john_15 luke_21  john_4  acts_15  john_2 john_1  john_1 john_5  john_3  luke_6  pro__23  john_3  john_1  john_2  john_2 john_5  rom_5 gen_4  deut_27  john_1 john_10  rom_150 sap_7  john_1 john_16 john__13  john_3 john_4  john_4 rom_9  rom_402  luke_2  deut_10  acts_10  luke_16  john_3  deut_18  rom_1 luke_12  num_33  num_13  luke_11  heb_7  num_33  num_33  num_33  heb_12  dan_8  luke_5  num_33 rom_6  john_20  luke_2  num_33  eccl_32  num_20 num_20 num_33  eccl_28  num_24  eph_3 eph_4 rom__9  acts_13  luke_1  eph_2  acts_4 dan_2  acts_5  acts_5 acts_10  rom_13 acts_1  acts_2  acts_2  col_2  acts_10  acts_10  phil_2  rom_13  luke_21  luke_1  luke_2  gen_3  acts_6  acts_6  dan_6  gen_13  gen_13  gen_13  gen_13  jude_7  acts_9  john_21  dan_6  gen_13  gen_13  gen_13  gen_13  jude_7  john_3  john_8  deut_10  john_2  luke_6  acts_16  acts_16  gen_22  john_4  john_2  matt_5 john_3 john_4 john_4 eccl_10 john_16 luke_6 eccl_9 gen_1 rom_2 john_2 john_2  john_4  john_4  john_5  eccl_7  john_3  john_19  luke_24  luke_1  john_14  luke_2  luke_2 rom_397  rom_100 phil_2  john__24  john_3  mark_1  deut_32  gen_2  acts_17 luke_19  john_4  john_3  john_4  john_17  john_12  col_9 col_272 col_503 col_686 col_1031 john_21  luke_6  sap_6  luke_6 gen_4  gen_1  gen_4  gen_25  gen_35  deut_32  gal_3  deut_34  deut_34  mark_16  rom_8  job_14  john_3  gen_4  gen_3  gen_3  sap_4  gen_25  deut_21  deut_21  deut_21  sap_2  sap_2  sap_2  sap_2  sap_2  luke_4  luke_4  luke_4  luke_4  luke_4  luke_4  luke_4  luke_4  sir_34  sir_34  luke_13  luke_13  luke_13  luke_6  luke_6  luke_23  john_14  eccl_5  eccl_5  luke_12  luke_12  gen_33  gen_21  gen_25  gen_30  gen_46  gen_4  gen_4  gen_4  deut_23  eccl_5  deut_8  deut_8  deut_8  deut_8  deut_8  deut_9  john_3  ...

# %%
#  to save the abbreviations into a file
with open("data/CSEL_PL_b_c.pkl", "wb") as f:
    pickle.dump(authors_b_c, f)
